# %%
import numpy as np

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Lambda

import gym
import tensorflow as tf
import matplotlib.pyplot as plt

import threading
import multiprocessing

# %%
def build_network1(state_dim, action_dim, action_bound):
    state_input = Input((state_dim,))
    h1 = Dense(64, activation='relu')(state_input)
    h2 = Dense(32, activation='relu')(h1)
    h3 = Dense(16, activation='relu')(h2)
    out_mu = Dense(action_dim, activation='tanh')(h3)
    std_output = Dense(action_dim, activation='softplus')(h3)

    # Scale output to [-action_bound, action_bound]
    mu_output = Lambda(lambda x: x * action_bound)(out_mu)
    model = Model(state_input, [mu_output, std_output])
    # model.summary()
    model._make_predict_function()  # class 안에서 def가 정의되면 필요없음
    return model

# %%
class Global_Actor(object):
    """
        Global Actor Network for A3C
    """
    def __init__(self, state_dim, action_dim, action_bound, learning_rate, entropy_beta):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.action_bound = action_bound
        self.learning_rate = learning_rate
        self.entropy_beta = entropy_beta

        self.std_bound = [1e-2, 1]  # std bound

        self.model = build_network1(self.state_dim,
                                                            self.action_dim,
                                                            self.action_bound)

        self.actor_optimizer = tf.keras.optimizers.Adam(self.learning_rate)



    ## log policy pdf
    def log_pdf(self, mu, std, action):
        std = tf.clip_by_value(std, self.std_bound[0], self.std_bound[1])
        var = std**2
        log_policy_pdf = -0.5 * (action - mu) ** 2 / var - 0.5 * tf.math.log(var * 2 * np.pi)
        entropy = 0.5 * (tf.math.log(2 * np.pi * std ** 2) + 1.0)
        return tf.reduce_sum(log_policy_pdf, 1, keepdims=True), tf.reduce_sum(entropy, 1, keepdims=True)


    ## train the actor network run by worker
    def train(self, states, actions, advantages):
        with tf.GradientTape() as tape:
            # policy pdf
            mu_a, std_a = self.model(states)
            log_policy_pdf, entropy = self.log_pdf(mu_a, std_a, actions)

            # loss function and its gradient
            loss_policy = log_policy_pdf * advantages
            loss = tf.reduce_sum(-loss_policy - self.entropy_beta * entropy)
        dj_dtheta = tape.gradient(loss, self.model.trainable_variables)

        # gradient clipping
        dj_dtheta, _ = tf.clip_by_global_norm(dj_dtheta, 40) #40

        # pretend gradient wrt global theta
        grads = zip(dj_dtheta, self.model.trainable_variables)
        self.actor_optimizer.apply_gradients(grads)

    ## actor prediction
    def predict(self, state):
        mu_a, _= self.model.predict(np.reshape(state, [1, self.state_dim]))
        return mu_a[0]

# %%
class Worker_Actor(object):
    """
        Worker Actor Network for A3C
    """
    def __init__(self, state_dim, action_dim, action_bound):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.action_bound = action_bound

        self.std_bound = [1e-2, 1]  # std bound

        self.model = build_network1(self.state_dim, self.action_dim, self.action_bound)


    ## actor policy
    def get_action(self, state):
        # type of action in env is numpy array
        # np.reshape(state, [1, self.state_dim]) : shape (state_dim,) -> shape (1, state_dim)
        # why [0]?  shape (1, action_dim) -> (action_dim,)
        mu_a, std_a = self.model.predict(np.reshape(state, [1, self.state_dim]))
        mu_a = mu_a[0]
        std_a = std_a[0]
        std_a = np.clip(std_a, self.std_bound[0], self.std_bound[1])
        action = np.random.normal(mu_a, std_a, size=self.action_dim)
        return action

# %%
def build_network2(state_dim):
    state_input = Input((state_dim,))
    h1 = Dense(64, activation='relu')(state_input)
    h2 = Dense(32, activation='relu')(h1)
    h3 = Dense(16, activation='relu')(h2)
    v_output = Dense(1, activation='linear')(h3)
    model = Model(state_input, v_output)
    #model.summary()
    model._make_predict_function()  # class 안에서 def가 정의되면 필요없음
    return model

# %%
class Global_Critic(object):
    """
        Global Critic Network for A3C: V function approximator
    """
    def __init__(self, state_dim, action_dim, learning_rate):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.learning_rate = learning_rate

        self.model = build_network2(state_dim)

        self.critic_optimizer = tf.keras.optimizers.Adam(self.learning_rate)


    ## train the critic network run by worker
    def train(self, states, td_targets):
        with tf.GradientTape() as tape:
            # loss function and its gradient
            v_values = self.model(states)
            loss = tf.reduce_sum(tf.square(td_targets-v_values))
        dj_dphi = tape.gradient(loss, self.model.trainable_variables)

        # gradient clipping
        dj_dphi, _ = tf.clip_by_global_norm(dj_dphi, 40) #40

        # gradients
        grads = zip(dj_dphi, self.model.trainable_variables)

        self.critic_optimizer.apply_gradients(grads)

# %%
class Worker_Critic(object):
    """
        Critic Network for A3C: V function approximator
    """
    def __init__(self, state_dim):

        self.model = build_network2(state_dim)

# %%
global_episode_count = 0
global_step = 0
global_episode_reward = []  # save the results


class A3Cagent(object):

    """
        Global network
    """
    def __init__(self, env_name):

        # training environment
        self.env_name = env_name
        self.WORKERS_NUM = multiprocessing.cpu_count() #4

        # hyperparameters
        self.ACTOR_LEARNING_RATE = 0.0001
        self.CRITIC_LEARNING_RATE = 0.001
        self.ENTROPY_BETA = 0.01

        # get state dimension
        env = gym.make(self.env_name)
        state_dim = env.observation_space.shape[0]
        # get action dimension
        action_dim = env.action_space.shape[0]
        # get action bound
        action_bound = env.action_space.high[0]

        # create global actor and critic networks
        self.global_actor = Global_Actor(state_dim, action_dim, action_bound, self.ACTOR_LEARNING_RATE,
                                         self.ENTROPY_BETA)
        self.global_critic = Global_Critic(state_dim, action_dim, self.CRITIC_LEARNING_RATE)


    def train(self, max_episode_num):

        workers = []

        # create worker
        for i in range(self.WORKERS_NUM):
            worker_name = 'worker%i' % i
            workers.append(A3Cworker(worker_name, self.env_name, self.global_actor,
                                     self.global_critic, max_episode_num))


         # create worker (multi-agents) and do parallel training
        for worker in workers:
            worker.start()

        for worker in workers:
            worker.join()

    
        print(global_episode_reward)


    ## save them to file if done
    def plot_result(self):
        plt.plot(global_episode_reward)
        plt.show()

# %%
class A3Cworker(threading.Thread):

    """
        local agent network (worker)
    """
    def __init__(self, worker_name, env_name, global_actor, global_critic, max_episode_num):
        threading.Thread.__init__(self)

        #self.lock = threading.Lock()

        # hyperparameters
        self.GAMMA = 0.95
        self.t_MAX = 4 # t-step prediction

        self.max_episode_num = max_episode_num

        # environment
        self.env = gym.make(env_name)
        self.worker_name = worker_name

        # global network sharing
        self.global_actor = global_actor
        self.global_critic = global_critic


        # get state dimension
        self.state_dim = self.env.observation_space.shape[0]
        # get action dimension
        self.action_dim = self.env.action_space.shape[0]
        # get action bound
        self.action_bound = self.env.action_space.high[0]

        # create local actor and critic networks
        self.worker_actor = Worker_Actor(self.state_dim, self.action_dim, self.action_bound)
        self.worker_critic = Worker_Critic(self.state_dim)

        # initial transfer global network parameters to worker network parameters
        self.worker_actor.model.set_weights(self.global_actor.model.get_weights())
        self.worker_critic.model.set_weights(self.global_critic.model.get_weights())


    ## computing Advantages and targets: y_k = r_k + gamma*V(s_k+1), A(s_k, a_k)= y_k - V(s_k)
    def n_step_td_target(self, rewards, next_v_value, done):
        td_targets = np.zeros_like(rewards)
        cumulative = 0
        if not done:
            cumulative = next_v_value

        for k in reversed(range(0, len(rewards))):
            cumulative = self.GAMMA * cumulative + rewards[k]
            td_targets[k] = cumulative
        return td_targets


    ## convert (list of np.array) to np.array
    def unpack_batch(self, batch):
        unpack = batch[0]
        for idx in range(len(batch) - 1):
            unpack = np.append(unpack, batch[idx + 1], axis=0)

        return unpack


    # train each worker
    def run(self):

        global global_episode_count, global_step
        global global_episode_reward  # total episode across all workers

        print(self.worker_name, "starts ---")

        while global_episode_count <= int(self.max_episode_num):

            # initialize batch
            batch_state, batch_action, batch_reward = [], [], []

            # reset episode
            step, episode_reward, done = 0, 0, False
            # reset the environment and observe the first state
            state = self.env.reset() # shape of state from gym (3,)

            while not done:

                # visualize the environment
                #self.env.render()
                # pick an action (shape of gym action = (action_dim,) )
                action = self.worker_actor.get_action(state)
                # clip continuous action to be within action_bound
                action = np.clip(action, -self.action_bound, self.action_bound)
                # observe reward, new_state, shape of output of gym (state_dim,)
                next_state, reward, done, _ = self.env.step(action)

                # change shape (state_dim,) -> (1, state_dim), same to action, next_state
                state = np.reshape(state, [1, self.state_dim])
                reward = np.reshape(reward, [1, 1])
                action = np.reshape(action, [1, self.action_dim])

                # append to the batch
                batch_state.append(state)
                batch_action.append(action)
                batch_reward.append((reward+8)/8) # <-- normalization
                #batch_reward.append(reward)

                # update state and step
                state = next_state
                step += 1
                episode_reward += reward[0]

                # if batch is full or episode ends, start to train global on batch
                if len(batch_state) == self.t_MAX or done:

                    # extract states, actions, rewards from batch
                    states = self.unpack_batch(batch_state)
                    actions = self.unpack_batch(batch_action)
                    rewards = self.unpack_batch(batch_reward)

                    # clear the batch
                    batch_state, batch_action, batch_reward = [], [], []

                    # compute n-step TD target and advantage prediction with global network
                    next_state = np.reshape(next_state, [1, self.state_dim])
                    next_v_value = self.global_critic.model.predict(next_state)
                    n_step_td_targets = self.n_step_td_target(rewards, next_v_value, done)
                    v_values = self.global_critic.model.predict(states)
                    advantages = n_step_td_targets - v_values


                    #with self.lock:
                    # update global critic
                    self.global_critic.train(states, n_step_td_targets)
                    # update global actor
                    self.global_actor.train(states, actions, advantages)

                    # transfer global network parameters to worker network parameters
                    self.worker_actor.model.set_weights(self.global_actor.model.get_weights())
                    self.worker_critic.model.set_weights(self.global_critic.model.get_weights())

                    # update global step
                    global_step += 1

                if done:
                    # update global episode count
                    global_episode_count += 1
                    ## display rewards every episode
                    print('Worker name:', self.worker_name, ', Episode: ', global_episode_count,
                          ', Step: ', step, ', Reward: ', episode_reward)

                    global_episode_reward.append(episode_reward)

# %%
max_episode_num = 1000
env_name = 'Pendulum-v0'
agent = A3Cagent(env_name)

agent.train(max_episode_num)

agent.plot_result()
# Out:
# c:\users\박정은\gym\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# worker0worker1 starts ---
#  worker2starts ---
#  starts ---
# worker3 starts ---
# WARNING:tensorflow:Layer dense_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Worker name: worker1 , Episode:  1 , Step:  200 , Reward:  [-1586.86088341]
# Worker name: worker2 , Episode:  2 , Step:  200 , Reward:  [-1831.57303752]
# Worker name: worker0 , Episode:  3 , Step:  200 , Reward:  [-1767.53285089]
# Worker name: worker3 , Episode:  4 , Step:  200 , Reward:  [-1385.13050343]
# Worker name: worker1 , Episode:  5 , Step:  200 , Reward:  [-1407.59708148]
# Worker name: worker2 , Episode:  6 , Step:  200 , Reward:  [-1142.26104887]
# Worker name: worker0 , Episode:  7 , Step:  200 , Reward:  [-1778.16612827]
# Worker name: worker3 , Episode:  8 , Step:  200 , Reward:  [-1314.28505335]
# Worker name: worker1 , Episode:  9 , Step:  200 , Reward:  [-1766.10060734]
# Worker name: worker2 , Episode:  10 , Step:  200 , Reward:  [-1335.65288368]
# Worker name: worker0 , Episode:  11 , Step:  200 , Reward:  [-1767.89767842]
# Worker name: worker3 , Episode:  12 , Step:  200 , Reward:  [-1725.17836041]
# Worker name: worker1 , Episode:  13 , Step:  200 , Reward:  [-1365.21866869]
# Worker name: worker0 , Episode:  14 , Step:  200 , Reward:  [-1532.63490033]
# Worker name: worker2 , Episode:  15 , Step:  200 , Reward:  [-1472.24700628]
# Worker name: worker3 , Episode:  16 , Step:  200 , Reward:  [-1298.44773459]
# Worker name: worker1 , Episode:  17 , Step:  200 , Reward:  [-1399.03205835]
# Worker name: worker0 , Episode:  18 , Step:  200 , Reward:  [-1356.44504625]
# Worker name: worker2 , Episode:  19 , Step:  200 , Reward:  [-1502.59413764]
# Worker name: worker3 , Episode:  20 , Step:  200 , Reward:  [-1581.69573848]
# Worker name: worker1 , Episode:  21 , Step:  200 , Reward:  [-1575.53197393]
# Worker name: worker0 , Episode:  22 , Step:  200 , Reward:  [-1270.66628615]
# Worker name: worker2 , Episode:  23 , Step:  200 , Reward:  [-1512.83626608]
# Worker name: worker3 , Episode:  24 , Step:  200 , Reward:  [-1372.78778926]
# Worker name: worker1 , Episode:  25 , Step:  200 , Reward:  [-1467.43891066]
# Worker name: worker0 , Episode:  26 , Step:  200 , Reward:  [-1169.2080888]
# Worker name: worker2 , Episode:  27 , Step:  200 , Reward:  [-1265.69974992]
# Worker name: worker3 , Episode:  28 , Step:  200 , Reward:  [-1165.44839351]
# Worker name: worker1 , Episode:  29 , Step:  200 , Reward:  [-1312.33023195]
# Worker name: worker0 , Episode:  30 , Step:  200 , Reward:  [-1403.73029944]
# Worker name: worker3 , Episode:  520 , Step:  200 , Reward:  [-384.66737487]
# Worker name: worker0 , Episode:  521 , Step:  200 , Reward:  [-132.82366163]
# Worker name: worker2 , Episode:  522 , Step:  200 , Reward:  [-1045.65438154]
# Worker name: worker1 , Episode:  523 , Step:  200 , Reward:  [-782.54992229]
# Worker name: worker3 , Episode:  524 , Step:  200 , Reward:  [-523.56735038]
# Worker name: worker0 , Episode:  525 , Step:  200 , Reward:  [-132.96567052]
# Worker name: worker2 , Episode:  526 , Step:  200 , Reward:  [-274.76640177]
# Worker name: worker1 , Episode:  527 , Step:  200 , Reward:  [-285.52887362]
# Worker name: worker3 , Episode:  528 , Step:  200 , Reward:  [-241.60785318]
# Worker name: worker0 , Episode:  529 , Step:  200 , Reward:  [-379.94642229]
# Worker name: worker2 , Episode:  530 , Step:  200 , Reward:  [-1151.89251513]
# Worker name: worker1 , Episode:  531 , Step:  200 , Reward:  [-393.21821221]
# Worker name: worker3 , Episode:  532 , Step:  200 , Reward:  [-2.09624827]
# Worker name: worker0 , Episode:  533 , Step:  200 , Reward:  [-2.185674]
# Worker name: worker2 , Episode:  534 , Step:  200 , Reward:  [-253.5108297]
# Worker name: worker1 , Episode:  535 , Step:  200 , Reward:  [-253.41314986]
# Worker name: worker3 , Episode:  536 , Step:  200 , Reward:  [-250.64786877]
# Worker name: worker0 , Episode:  537 , Step:  200 , Reward:  [-249.40562267]
# Worker name: worker2 , Episode:  538 , Step:  200 , Reward:  [-128.65176554]
# Worker name: worker1 , Episode:  539 , Step:  200 , Reward:  [-126.52297461]
# Worker name: worker3 , Episode:  540 , Step:  200 , Reward:  [-258.93279323]
# Worker name: worker0 , Episode:  541 , Step:  200 , Reward:  [-129.85178674]
# Worker name: worker2 , Episode:  542 , Step:  200 , Reward:  [-245.60042873]
# Worker name: worker1 , Episode:  543 , Step:  200 , Reward:  [-917.75011848]
# Worker name: worker3 , Episode:  544 , Step:  200 , Reward:  [-262.60267198]
# Worker name: worker0 , Episode:  545 , Step:  200 , Reward:  [-389.97195189]
# Worker name: worker2 , Episode:  546 , Step:  200 , Reward:  [-131.50186985]
# Worker name: worker1 , Episode:  547 , Step:  200 , Reward:  [-256.48414016]
# ...
# Worker name: worker2 , Episode:  849 , Step:  200 , Reward:  [-657.72065735]
# Worker name: worker0 , Episode:  850 , Step:  200 , Reward:  [-132.21581054]
# Worker name: worker1 , Episode:  851 , Step:  200 , Reward:  [-392.01654197]
# Worker name: worker3 , Episode:  852 , Step:  200 , Reward:  [-402.96405914]
# Worker name: worker2 , Episode:  853 , Step:  200 , Reward:  [-252.07256522]
# Worker name: worker0 , Episode:  854 , Step:  200 , Reward:  [-131.748661]
# Worker name: worker1 , Episode:  855 , Step:  200 , Reward:  [-255.51096378]
# Worker name: worker3 , Episode:  856 , Step:  200 , Reward:  [-1.23221442]
# Worker name: worker0 , Episode:  857 , Step:  200 , Reward:  [-395.12901871]
# Worker name: worker2 , Episode:  858 , Step:  200 , Reward:  [-398.38990757]
# Worker name: worker1 , Episode:  859 , Step:  200 , Reward:  [-135.59970514]
# Worker name: worker3 , Episode:  860 , Step:  200 , Reward:  [-129.03822142]
# Worker name: worker0 , Episode:  861 , Step:  200 , Reward:  [-304.37554968]
# Worker name: worker2 , Episode:  862 , Step:  200 , Reward:  [-263.8686265]
# Worker name: worker1 , Episode:  863 , Step:  200 , Reward:  [-128.16756306]
# Worker name: worker3 , Episode:  864 , Step:  200 , Reward:  [-383.11186777]
# Worker name: worker0 , Episode:  865 , Step:  200 , Reward:  [-788.51109554]
# Worker name: worker2 , Episode:  866 , Step:  200 , Reward:  [-283.95352161]
# Worker name: worker1 , Episode:  867 , Step:  200 , Reward:  [-126.70709586]
# Worker name: worker3 , Episode:  868 , Step:  200 , Reward:  [-3.20809562]
# Worker name: worker0 , Episode:  869 , Step:  200 , Reward:  [-127.92001202]
# Worker name: worker2 , Episode:  870 , Step:  200 , Reward:  [-1148.67775922]
# Worker name: worker1 , Episode:  871 , Step:  200 , Reward:  [-1.90222163]
# Worker name: worker3 , Episode:  872 , Step:  200 , Reward:  [-976.69452007]
# Worker name: worker0 , Episode:  873 , Step:  200 , Reward:  [-394.53398638]
# Worker name: worker2 , Episode:  874 , Step:  200 , Reward:  [-130.42303171]
# Worker name: worker1 , Episode:  875 , Step:  200 , Reward:  [-268.10111323]
# Worker name: worker3 , Episode:  876 , Step:  200 , Reward:  [-1.02903954]
# Worker name: worker0 , Episode:  877 , Step:  200 , Reward:  [-131.38290839]
# Worker name: worker2 , Episode:  878 , Step:  200 , Reward:  [-265.63025563]
# Worker name: worker1 , Episode:  879 , Step:  200 , Reward:  [-131.02746551]
# Worker name: worker3 , Episode:  880 , Step:  200 , Reward:  [-253.39435519]
# Worker name: worker0 , Episode:  881 , Step:  200 , Reward:  [-386.87926785]
# Worker name: worker2 , Episode:  882 , Step:  200 , Reward:  [-132.58904093]
# Worker name: worker1 , Episode:  883 , Step:  200 , Reward:  [-1.3281311]
# Worker name: worker3 , Episode:  884 , Step:  200 , Reward:  [-130.46320037]
# Worker name: worker0 , Episode:  885 , Step:  200 , Reward:  [-2.59575469]
# Worker name: worker2 , Episode:  886 , Step:  200 , Reward:  [-942.31711648]
# Worker name: worker1 , Episode:  887 , Step:  200 , Reward:  [-131.47576045]
# Worker name: worker3 , Episode:  888 , Step:  200 , Reward:  [-525.99142764]
# Worker name: worker0 , Episode:  889 , Step:  200 , Reward:  [-129.41987202]
# Worker name: worker2 , Episode:  890 , Step:  200 , Reward:  [-2.85928959]
# Worker name: worker1 , Episode:  891 , Step:  200 , Reward:  [-256.62946913]
# Worker name: worker3 , Episode:  892 , Step:  200 , Reward:  [-254.21572774]
# Worker name: worker0 , Episode:  893 , Step:  200 , Reward:  [-271.34445923]
# Worker name: worker2 , Episode:  894 , Step:  200 , Reward:  [-257.26217299]
# Worker name: worker1 , Episode:  895 , Step:  200 , Reward:  [-133.99765469]
# Worker name: worker3 , Episode:  896 , Step:  200 , Reward:  [-1.77789976]
# Worker name: worker0 , Episode:  897 , Step:  200 , Reward:  [-267.11327692]
# Worker name: worker2 , Episode:  898 , Step:  200 , Reward:  [-129.52087826]
# Worker name: worker1 , Episode:  899 , Step:  200 , Reward:  [-3.62000486]
# Worker name: worker3 , Episode:  900 , Step:  200 , Reward:  [-130.0410568]
# Worker name: worker0 , Episode:  901 , Step:  200 , Reward:  [-266.57574135]
# Worker name: worker2 , Episode:  902 , Step:  200 , Reward:  [-247.11310553]
# Worker name: worker1 , Episode:  903 , Step:  200 , Reward:  [-250.38096066]
# Worker name: worker3 , Episode:  904 , Step:  200 , Reward:  [-376.98705156]
# Worker name: worker0 , Episode:  905 , Step:  200 , Reward:  [-258.13002823]
# Worker name: worker2 , Episode:  906 , Step:  200 , Reward:  [-129.59304478]
# Worker name: worker1 , Episode:  907 , Step:  200 , Reward:  [-129.71097218]
# Worker name: worker3 , Episode:  908 , Step:  200 , Reward:  [-263.97298686]
# Worker name: worker0 , Episode:  909 , Step:  200 , Reward:  [-264.43155775]
# Worker name: worker2 , Episode:  910 , Step:  200 , Reward:  [-1.22763804]
# Worker name: worker1 , Episode:  911 , Step:  200 , Reward:  [-378.80683084]
# Worker name: worker3 , Episode:  912 , Step:  200 , Reward:  [-134.61486673]
# Worker name: worker0 , Episode:  913 , Step:  200 , Reward:  [-131.60861814]
# Worker name: worker2 , Episode:  914 , Step:  200 , Reward:  [-263.66579684]
# Worker name: worker1 , Episode:  915 , Step:  200 , Reward:  [-267.148046]
# Worker name: worker3 , Episode:  916 , Step:  200 , Reward:  [-126.97692963]
# Worker name: worker0 , Episode:  917 , Step:  200 , Reward:  [-130.71819815]
# Worker name: worker2 , Episode:  918 , Step:  200 , Reward:  [-385.76724033]
# Worker name: worker1 , Episode:  919 , Step:  200 , Reward:  [-133.92021622]
# Worker name: worker3 , Episode:  920 , Step:  200 , Reward:  [-266.08764604]
# Worker name: worker0 , Episode:  921 , Step:  200 , Reward:  [-133.78165333]
# Worker name: worker2 , Episode:  922 , Step:  200 , Reward:  [-2.41746506]
# Worker name: worker1 , Episode:  923 , Step:  200 , Reward:  [-128.20923339]
# Worker name: worker3 , Episode:  924 , Step:  200 , Reward:  [-137.90515704]
# Worker name: worker0 , Episode:  925 , Step:  200 , Reward:  [-129.15520639]
# Worker name: worker2 , Episode:  926 , Step:  200 , Reward:  [-130.64964679]
# Worker name: worker1 , Episode:  927 , Step:  200 , Reward:  [-391.94561286]
# Worker name: worker3 , Episode:  928 , Step:  200 , Reward:  [-131.43381511]
# Worker name: worker0 , Episode:  929 , Step:  200 , Reward:  [-258.14053095]
# Worker name: worker2 , Episode:  930 , Step:  200 , Reward:  [-382.4552507]
# Worker name: worker1 , Episode:  931 , Step:  200 , Reward:  [-519.61386104]
# Worker name: worker3 , Episode:  932 , Step:  200 , Reward:  [-244.03804266]
# Worker name: worker0 , Episode:  933 , Step:  200 , Reward:  [-130.83739669]
# Worker name: worker2 , Episode:  934 , Step:  200 , Reward:  [-380.57192269]
# Worker name: worker1 , Episode:  935 , Step:  200 , Reward:  [-131.67594009]
# Worker name: worker3 , Episode:  936 , Step:  200 , Reward:  [-127.79814532]
# Worker name: worker0 , Episode:  937 , Step:  200 , Reward:  [-131.57094838]
# Worker name: worker2 , Episode:  938 , Step:  200 , Reward:  [-242.84401862]
# Worker name: worker1 , Episode:  939 , Step:  200 , Reward:  [-411.28993106]
# Worker name: worker3 , Episode:  940 , Step:  200 , Reward:  [-130.52304613]
# Worker name: worker0 , Episode:  941 , Step:  200 , Reward:  [-271.06672176]
# Worker name: worker2 , Episode:  942 , Step:  200 , Reward:  [-395.90877948]
# Worker name: worker1 , Episode:  943 , Step:  200 , Reward:  [-131.482295]
# Worker name: worker3 , Episode:  944 , Step:  200 , Reward:  [-2.22808877]
# Worker name: worker0 , Episode:  945 , Step:  200 , Reward:  [-133.02659293]
# Worker name: worker2 , Episode:  946 , Step:  200 , Reward:  [-1.01261517]
# Worker name: worker1 , Episode:  947 , Step:  200 , Reward:  [-1.85308288]
# Worker name: worker3 , Episode:  948 , Step:  200 , Reward:  [-132.05022636]
# Worker name: worker0 , Episode:  949 , Step:  200 , Reward:  [-129.99499073]
# Worker name: worker2 , Episode:  950 , Step:  200 , Reward:  [-252.24484198]
# Worker name: worker1 , Episode:  951 , Step:  200 , Reward:  [-3.31589749]
# Worker name: worker3 , Episode:  952 , Step:  200 , Reward:  [-134.20021665]
# Worker name: worker0 , Episode:  953 , Step:  200 , Reward:  [-375.9329565]
# Worker name: worker2 , Episode:  954 , Step:  200 , Reward:  [-1.28859474]
# Worker name: worker1 , Episode:  955 , Step:  200 , Reward:  [-259.03332805]
# Worker name: worker3 , Episode:  956 , Step:  200 , Reward:  [-128.82311381]
# Worker name: worker0 , Episode:  957 , Step:  200 , Reward:  [-399.85593256]
# Worker name: worker2 , Episode:  958 , Step:  200 , Reward:  [-126.16121586]
# Worker name: worker1 , Episode:  959 , Step:  200 , Reward:  [-397.24106033]
# Worker name: worker3 , Episode:  960 , Step:  200 , Reward:  [-258.63302066]
# Worker name: worker0 , Episode:  961 , Step:  200 , Reward:  [-134.66189794]
# Worker name: worker2 , Episode:  962 , Step:  200 , Reward:  [-129.62456753]
# Worker name: worker1 , Episode:  963 , Step:  200 , Reward:  [-376.43986329]
# Worker name: worker3 , Episode:  964 , Step:  200 , Reward:  [-624.34600467]
# Worker name: worker0 , Episode:  965 , Step:  200 , Reward:  [-355.72629665]
# Worker name: worker2 , Episode:  966 , Step:  200 , Reward:  [-130.39406411]
# Worker name: worker1 , Episode:  967 , Step:  200 , Reward:  [-130.09605095]
# Worker name: worker3 , Episode:  968 , Step:  200 , Reward:  [-245.764383]
# Worker name: worker0 , Episode:  969 , Step:  200 , Reward:  [-262.3830158]
# Worker name: worker2 , Episode:  970 , Step:  200 , Reward:  [-129.13079818]
# Worker name: worker1 , Episode:  971 , Step:  200 , Reward:  [-129.60696969]
# Worker name: worker3 , Episode:  972 , Step:  200 , Reward:  [-128.92518521]
