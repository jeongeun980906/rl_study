# %%
import numpy as np

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Lambda
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt
import gym

# %%
class Actor(object):
    """
        Actor Network for PPO
    """
    def __init__(self, state_dim, action_dim, action_bound, learning_rate, ratio_clipping):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.action_bound = action_bound
        self.learning_rate = learning_rate
        self.ratio_clipping = ratio_clipping

        self.std_bound = [1e-2, 1.0] # std bound

        self.model = self.build_network()

        self.actor_optimizer = tf.keras.optimizers.Adam(self.learning_rate)

    ## actor network
    def build_network(self):
        state_input = Input((self.state_dim,))
        h1 = Dense(64, activation='relu')(state_input)
        h2 = Dense(32, activation='relu')(h1)
        h3 = Dense(16, activation='relu')(h2)
        out_mu = Dense(self.action_dim, activation='tanh')(h3)
        std_output = Dense(self.action_dim, activation='softplus')(h3)

        # Scale output to [-action_bound, action_bound]
        mu_output = Lambda(lambda x: x*self.action_bound)(out_mu)
        model = Model(state_input, [mu_output, std_output])
        model.summary()
        return model


    ## log policy pdf
    def log_pdf(self, mu, std, action):
        std = tf.clip_by_value(std, self.std_bound[0], self.std_bound[1])
        var = std**2
        log_policy_pdf = -0.5 * (action - mu) ** 2 / var - 0.5 * tf.math.log(var * 2 * np.pi)
        return tf.reduce_sum(log_policy_pdf, 1, keepdims=True)


    ## actor policy
    def get_policy_action(self, state):
        # type of action in env is numpy array
        # np.reshape(state, [1, self.state_dim]) : shape (state_dim,) -> shape (1, state_dim)
        # why [0]?  shape (1, action_dim) -> (action_dim,)
        mu_a, std_a = self.model.predict(np.reshape(state, [1, self.state_dim]))
        mu_a = mu_a[0]
        std_a = std_a[0]
        std_a = np.clip(std_a, self.std_bound[0], self.std_bound[1])
        action = np.random.normal(mu_a, std_a, size=self.action_dim)
        return mu_a, std_a, action

    ## actor prediction
    def predict(self, state):
        mu_a, _= self.model.predict(np.reshape(state, [1, self.state_dim]))
        return mu_a[0]


    ## train the actor network
    def train(self, log_old_policy_pdf, states, actions, advantages):
        with tf.GradientTape() as tape:
            # current policy pdf
            mu_a, std_a = self.model(states)
            log_policy_pdf = self.log_pdf(mu_a, std_a, actions)

            # ratio of current and old policies
            ratio = tf.exp(log_policy_pdf - log_old_policy_pdf)
            clipped_ratio = tf.clip_by_value(ratio, 1.0-self.ratio_clipping, 1.0+self.ratio_clipping)
            surrogate = -tf.minimum(ratio * advantages, clipped_ratio * advantages)
            loss = tf.reduce_mean(surrogate)
        dj_dtheta = tape.gradient(loss, self.model.trainable_variables)
        grads = zip(dj_dtheta, self.model.trainable_variables)
        self.actor_optimizer.apply_gradients(grads)

# %%
class Critic(object):
    """
        Critic Network for PPO: V function approximator
    """
    def __init__(self, state_dim, action_dim, learning_rate):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.learning_rate = learning_rate

        # create and compile critic network
        self.model, self.states = self.build_network()

        self.model.compile(optimizer=Adam(self.learning_rate), loss='mse')

    ## critic network
    def build_network(self):
        state_input = Input((self.state_dim,))
        h1 = Dense(64, activation='relu')(state_input)
        h2 = Dense(32, activation='relu')(h1)
        h3 = Dense(16, activation='relu')(h2)
        v_output = Dense(1, activation='linear')(h3)
        model = Model(state_input, v_output)
        model.summary()
        return model, state_input


    ## single gradient update on a single batch data
    def train_on_batch(self, states, td_targets):
        return self.model.train_on_batch(states, td_targets)

# %%
class PPOagent(object):

    def __init__(self, env):

        # hyperparameters
        self.GAMMA = 0.95
        self.GAE_LAMBDA = 0.9 #0.8
        self.BATCH_SIZE = 64
        self.ACTOR_LEARNING_RATE = 0.0001
        self.CRITIC_LEARNING_RATE = 0.001
        self.RATIO_CLIPPING = 0.2
        self.EPOCHS = 10

        self.env = env
        # get state dimension
        self.state_dim = env.observation_space.shape[0]
        # get action dimension
        self.action_dim = env.action_space.shape[0]
        # get action bound
        self.action_bound = env.action_space.high[0]

        # create actor and critic networks
        self.actor = Actor(self.state_dim, self.action_dim, self.action_bound,
                           self.ACTOR_LEARNING_RATE, self.RATIO_CLIPPING)
        self.critic = Critic(self.state_dim, self.action_dim, self.CRITIC_LEARNING_RATE)

        # save the results
        self.save_epi_reward = []


    ## computing Advantages and targets: y_k = r_k + gamma*V(s_k+1), A(s_k, a_k)= y_k - V(s_k)
    def gae_target(self, rewards, v_values, next_v_value, done):
        n_step_targets = np.zeros_like(rewards)
        gae = np.zeros_like(rewards)
        gae_cumulative = 0
        forward_val = 0

        if not done:
            forward_val = next_v_value

        for k in reversed(range(0, len(rewards))):
            delta = rewards[k] + self.GAMMA * forward_val - v_values[k]
            gae_cumulative = self.GAMMA * self.GAE_LAMBDA * gae_cumulative + delta
            gae[k] = gae_cumulative
            forward_val = v_values[k]
            n_step_targets[k] = gae[k] + v_values[k]
        return gae, n_step_targets


    ## convert (list of np.array) to np.array
    def unpack_batch(self, batch):
        unpack = batch[0]
        for idx in range(len(batch)-1):
            unpack = np.append(unpack, batch[idx+1], axis=0)

        return unpack


    ## train the agent
    def train(self, max_episode_num):

        # initialize batch
        batch_state, batch_action, batch_reward = [], [], []
        batch_log_old_policy_pdf = []

        for ep in range(int(max_episode_num)):

            # reset episode
            time, episode_reward, done = 0, 0, False
            # reset the environment and observe the first state
            state = self.env.reset() # shape of state from gym (3,)

            while not done:

                # visualize the environment
                #self.env.render()
                # compute mu and std of old policy and pick an action (shape of gym action = (action_dim,) )
                mu_old, std_old, action = self.actor.get_policy_action(state)
                # clip continuous action to be within action_bound
                action = np.clip(action, -self.action_bound, self.action_bound)
                # compute log old policy pdf
                var_old = std_old ** 2
                log_old_policy_pdf = -0.5 * (action - mu_old) ** 2 / var_old - 0.5 * np.log(var_old * 2 * np.pi)
                log_old_policy_pdf = np.sum(log_old_policy_pdf)
                # observe reward, new_state, shape of output of gym (state_dim,)
                next_state, reward, done, _ = self.env.step(action)
                # change shape (state_dim,) -> (1, state_dim), same to mu, std, action
                state = np.reshape(state, [1, self.state_dim])
                action = np.reshape(action, [1, self.action_dim])
                reward = np.reshape(reward, [1, 1])
                log_old_policy_pdf = np.reshape(log_old_policy_pdf, [1, 1])

                # append to the batch
                batch_state.append(state)
                batch_action.append(action)
                batch_reward.append((reward+8)/8) # <-- normalization
                #batch_reward.append(reward)
                batch_log_old_policy_pdf.append(log_old_policy_pdf)

                # continue until batch becomes full
                if len(batch_state) < self.BATCH_SIZE:
                    # update current state
                    state = next_state
                    episode_reward += reward[0]
                    time += 1
                    continue

                # extract batched states, actions, td_targets, advantages
                states = self.unpack_batch(batch_state)
                actions = self.unpack_batch(batch_action)
                rewards = self.unpack_batch(batch_reward)
                log_old_policy_pdfs = self.unpack_batch(batch_log_old_policy_pdf)

                # clear the batch
                batch_state, batch_action, batch_reward = [], [], []
                batch_log_old_policy_pdf = []

                # compute gae and TD targets
                next_state = np.reshape(next_state, [1, self.state_dim])
                next_v_value = self.critic.model.predict(next_state)
                v_values = self.critic.model.predict(states)
                gaes, y_i = self.gae_target(rewards, v_values, next_v_value, done)

                # update the networks
                for _ in range(self.EPOCHS):

                    # train
                    self.actor.train(log_old_policy_pdfs, states, actions, gaes)
                    self.critic.train_on_batch(states, y_i)

                # update current state
                state = next_state
                episode_reward += reward[0]
                time += 1

            ## display rewards every episode
            print('Episode: ', ep+1, 'Time: ', time, 'Reward: ', episode_reward)

            self.save_epi_reward.append(episode_reward)
        print(self.save_epi_reward)


    ## save them to file if done
    def plot_result(self):
        plt.plot(self.save_epi_reward)
        plt.show()

# %%
max_episode_num = 1000
env_name = 'Pendulum-v0'
env = gym.make(env_name)
agent = PPOagent(env)

agent.train(max_episode_num)

agent.plot_result()
# Out:
# c:\users\박정은\gym\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           256         input_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           2080        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 16)           528         dense_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            17          dense_11[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            17          dense_11[0][0]
# ==================================================================================================
# Total params: 2,898
# Trainable params: 2,898
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                256
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_16 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Episode:  1 Time:  200 Reward:  [-1395.96051877]
# Episode:  2 Time:  200 Reward:  [-1233.08959234]
# Episode:  3 Time:  200 Reward:  [-1341.48302513]
# Episode:  4 Time:  200 Reward:  [-1433.95290763]
# Episode:  5 Time:  200 Reward:  [-1747.36646792]
# Episode:  6 Time:  200 Reward:  [-1155.6473278]
# Episode:  7 Time:  200 Reward:  [-1409.72056092]
# Episode:  8 Time:  200 Reward:  [-1794.54102949]
# Episode:  9 Time:  200 Reward:  [-1484.53599404]
# Episode:  10 Time:  200 Reward:  [-1434.22180123]
# Episode:  11 Time:  200 Reward:  [-1254.7725545]
# Episode:  12 Time:  200 Reward:  [-1334.0343137]
# Episode:  13 Time:  200 Reward:  [-1397.7570261]
# Episode:  14 Time:  200 Reward:  [-1200.49362083]
# Episode:  15 Time:  200 Reward:  [-1241.16246762]
# Episode:  16 Time:  200 Reward:  [-1293.27990232]
# Episode:  17 Time:  200 Reward:  [-1220.81788628]
# Episode:  18 Time:  200 Reward:  [-1342.77060769]
# Episode:  19 Time:  200 Reward:  [-1408.74589327]
# Episode:  20 Time:  200 Reward:  [-1510.14110286]
# Episode:  21 Time:  200 Reward:  [-1659.86946001]
# Episode:  22 Time:  200 Reward:  [-1402.06638938]
# Episode:  23 Time:  200 Reward:  [-1443.42749469]
# Episode:  24 Time:  200 Reward:  [-1505.12042869]
# Episode:  25 Time:  200 Reward:  [-1408.46861479]
# Episode:  26 Time:  200 Reward:  [-1439.99401724]
# Episode:  27 Time:  200 Reward:  [-1342.8029064]
# Episode:  28 Time:  200 Reward:  [-1162.55896244]
# Episode:  29 Time:  200 Reward:  [-1862.02982129]
# Episode:  30 Time:  200 Reward:  [-1340.34619604]
# Episode:  31 Time:  200 Reward:  [-1510.13476765]
# Episode:  32 Time:  200 Reward:  [-1692.78103962]
# Episode:  33 Time:  200 Reward:  [-1805.64313087]
# Episode:  34 Time:  200 Reward:  [-1676.39330399]
# Episode:  35 Time:  200 Reward:  [-1859.70573466]
# Episode:  36 Time:  200 Reward:  [-1346.24367149]
# Episode:  37 Time:  200 Reward:  [-1369.04275417]
# Episode:  38 Time:  200 Reward:  [-1702.94221571]
# Episode:  39 Time:  200 Reward:  [-1239.52077504]
# Episode:  40 Time:  200 Reward:  [-1226.84371278]
# Episode:  41 Time:  200 Reward:  [-1156.1568855]
# Episode:  42 Time:  200 Reward:  [-1092.91193263]
# Episode:  43 Time:  200 Reward:  [-1317.73251662]
# Episode:  44 Time:  200 Reward:  [-1189.25098433]
# Episode:  45 Time:  200 Reward:  [-1259.99954456]
# Episode:  46 Time:  200 Reward:  [-1097.79092615]
# Episode:  47 Time:  200 Reward:  [-1716.93930888]
# Episode:  48 Time:  200 Reward:  [-1287.9893454]
# Episode:  49 Time:  200 Reward:  [-1326.49379173]
# Episode:  50 Time:  200 Reward:  [-1266.73203623]
# Episode:  51 Time:  200 Reward:  [-1277.50306853]
# Episode:  52 Time:  200 Reward:  [-1518.30217341]
# Episode:  53 Time:  200 Reward:  [-1491.03677571]
# Episode:  54 Time:  200 Reward:  [-1199.16389087]
# Episode:  55 Time:  200 Reward:  [-1031.1854707]
# Episode:  56 Time:  200 Reward:  [-1494.56664726]
# Episode:  57 Time:  200 Reward:  [-1469.7634743]
# Episode:  58 Time:  200 Reward:  [-1343.7811809]
# Episode:  59 Time:  200 Reward:  [-1321.71902632]
# Episode:  60 Time:  200 Reward:  [-1211.42363483]
# Episode:  61 Time:  200 Reward:  [-1442.56590024]
# Episode:  62 Time:  200 Reward:  [-1414.05520974]
# Episode:  63 Time:  200 Reward:  [-1300.83770657]
# Episode:  64 Time:  200 Reward:  [-1181.5027599]
# Episode:  65 Time:  200 Reward:  [-1306.96635969]
# Episode:  66 Time:  200 Reward:  [-1356.53147496]
# Episode:  67 Time:  200 Reward:  [-1172.48614177]
# Episode:  68 Time:  200 Reward:  [-1310.55925938]
# Episode:  69 Time:  200 Reward:  [-1308.76071879]
# Episode:  70 Time:  200 Reward:  [-1324.04161542]
# Episode:  71 Time:  200 Reward:  [-1263.96261137]
# Episode:  72 Time:  200 Reward:  [-1327.62337434]
# Episode:  73 Time:  200 Reward:  [-1022.48339167]
# Episode:  74 Time:  200 Reward:  [-1090.94550485]
# Episode:  75 Time:  200 Reward:  [-1006.43581192]
# Episode:  76 Time:  200 Reward:  [-1295.234748]
# Episode:  77 Time:  200 Reward:  [-1197.93350774]
# Episode:  78 Time:  200 Reward:  [-1297.45153664]
# Episode:  79 Time:  200 Reward:  [-1303.53530341]
# Episode:  80 Time:  200 Reward:  [-1124.91186805]
# Episode:  81 Time:  200 Reward:  [-1201.78923496]
# Episode:  82 Time:  200 Reward:  [-1318.19926612]
# Episode:  83 Time:  200 Reward:  [-1205.59692745]
# Episode:  84 Time:  200 Reward:  [-1155.99241346]
# Episode:  85 Time:  200 Reward:  [-890.02039804]
# Episode:  86 Time:  200 Reward:  [-1296.72107745]
# Episode:  87 Time:  200 Reward:  [-1259.12105495]
# Episode:  88 Time:  200 Reward:  [-754.35395085]
# Episode:  89 Time:  200 Reward:  [-1188.53188933]
# Episode:  90 Time:  200 Reward:  [-657.56169806]
# Episode:  91 Time:  200 Reward:  [-1109.7715214]
# Episode:  92 Time:  200 Reward:  [-961.78293167]
# Episode:  93 Time:  200 Reward:  [-978.63487295]
# Episode:  94 Time:  200 Reward:  [-628.11182503]
# Episode:  95 Time:  200 Reward:  [-856.54376453]
# Episode:  96 Time:  200 Reward:  [-1123.10208011]
# Episode:  97 Time:  200 Reward:  [-1126.9832052]
# Episode:  98 Time:  200 Reward:  [-1033.58280454]
# Episode:  99 Time:  200 Reward:  [-759.11224587]
# Episode:  100 Time:  200 Reward:  [-969.87746913]
# Episode:  101 Time:  200 Reward:  [-749.88280398]
# Episode:  102 Time:  200 Reward:  [-754.59908911]
# Episode:  103 Time:  200 Reward:  [-1014.37846986]
# Episode:  104 Time:  200 Reward:  [-1023.46548744]
# Episode:  105 Time:  200 Reward:  [-1156.44936873]
# Episode:  106 Time:  200 Reward:  [-770.77239557]
# Episode:  107 Time:  200 Reward:  [-772.66921482]
# Episode:  108 Time:  200 Reward:  [-880.80739676]
# Episode:  109 Time:  200 Reward:  [-877.69213466]
# Episode:  110 Time:  200 Reward:  [-888.30439455]
# Episode:  111 Time:  200 Reward:  [-829.60949531]
# Episode:  112 Time:  200 Reward:  [-849.51183845]
# Episode:  113 Time:  200 Reward:  [-1062.80123733]
# Episode:  114 Time:  200 Reward:  [-896.00822742]
# Episode:  115 Time:  200 Reward:  [-811.88954389]
# Episode:  116 Time:  200 Reward:  [-1237.99707988]
# Episode:  117 Time:  200 Reward:  [-1124.87990701]
# Episode:  118 Time:  200 Reward:  [-1065.4293359]
# Episode:  119 Time:  200 Reward:  [-877.97139086]
# Episode:  120 Time:  200 Reward:  [-737.53063723]
# Episode:  121 Time:  200 Reward:  [-631.69778764]
# Episode:  122 Time:  200 Reward:  [-870.70902648]
# Episode:  123 Time:  200 Reward:  [-1094.69447788]
# Episode:  124 Time:  200 Reward:  [-708.18734888]
# Episode:  125 Time:  200 Reward:  [-742.14447076]
# Episode:  126 Time:  200 Reward:  [-759.59455645]
# Episode:  127 Time:  200 Reward:  [-1077.24064551]
# Episode:  128 Time:  200 Reward:  [-864.27106097]
# Episode:  129 Time:  200 Reward:  [-890.19513684]
# Episode:  130 Time:  200 Reward:  [-865.10784688]
# Episode:  131 Time:  200 Reward:  [-782.56489426]
# Episode:  132 Time:  200 Reward:  [-977.46783659]
# Episode:  133 Time:  200 Reward:  [-912.02649974]
# Episode:  134 Time:  200 Reward:  [-865.46712028]
# Episode:  135 Time:  200 Reward:  [-776.74105432]
# Episode:  136 Time:  200 Reward:  [-1025.96005533]
# Episode:  137 Time:  200 Reward:  [-887.74199698]
# Episode:  138 Time:  200 Reward:  [-996.29421122]
# Episode:  139 Time:  200 Reward:  [-982.13692999]
# Episode:  140 Time:  200 Reward:  [-662.92759248]
# Episode:  141 Time:  200 Reward:  [-870.07859832]
# Episode:  142 Time:  200 Reward:  [-752.49929358]
# Episode:  143 Time:  200 Reward:  [-869.45307963]
# Episode:  144 Time:  200 Reward:  [-271.76411753]
# Episode:  145 Time:  200 Reward:  [-878.76512649]
# Episode:  146 Time:  200 Reward:  [-753.45812678]
# Episode:  147 Time:  200 Reward:  [-747.24974611]
# Episode:  148 Time:  200 Reward:  [-806.25176624]
# Episode:  149 Time:  200 Reward:  [-910.37641741]
# Episode:  150 Time:  200 Reward:  [-628.52872452]
# Episode:  151 Time:  200 Reward:  [-1015.20364166]
# Episode:  152 Time:  200 Reward:  [-736.6398495]
# Episode:  153 Time:  200 Reward:  [-508.82451005]
# Episode:  154 Time:  200 Reward:  [-1016.4278843]
# Episode:  155 Time:  200 Reward:  [-1116.57955851]
# Episode:  156 Time:  200 Reward:  [-761.04373476]
# Episode:  157 Time:  200 Reward:  [-1142.27123577]
# Episode:  158 Time:  200 Reward:  [-1009.14335691]
# Episode:  159 Time:  200 Reward:  [-882.98859587]
# Episode:  160 Time:  200 Reward:  [-903.62128431]
# Episode:  161 Time:  200 Reward:  [-698.57037654]
# Episode:  162 Time:  200 Reward:  [-1171.291694]
# Episode:  163 Time:  200 Reward:  [-765.2129193]
# Episode:  164 Time:  200 Reward:  [-876.77764316]
# Episode:  165 Time:  200 Reward:  [-940.30191074]
# Episode:  166 Time:  200 Reward:  [-950.64351888]
# Episode:  167 Time:  200 Reward:  [-629.87861274]
# Episode:  168 Time:  200 Reward:  [-748.19300104]
# Episode:  169 Time:  200 Reward:  [-918.33447931]
# Episode:  170 Time:  200 Reward:  [-1248.89821832]
# Episode:  171 Time:  200 Reward:  [-1270.85354397]
# Episode:  172 Time:  200 Reward:  [-1056.67955887]
# Episode:  173 Time:  200 Reward:  [-509.85097062]
# Episode:  174 Time:  200 Reward:  [-878.75299449]
# Episode:  175 Time:  200 Reward:  [-1184.66247646]
# Episode:  176 Time:  200 Reward:  [-776.19110357]
# Episode:  177 Time:  200 Reward:  [-913.34030739]
# Episode:  178 Time:  200 Reward:  [-398.08530377]
# Episode:  179 Time:  200 Reward:  [-531.96402168]
# Episode:  180 Time:  200 Reward:  [-804.34521212]
# Episode:  181 Time:  200 Reward:  [-1036.69586076]
# Episode:  182 Time:  200 Reward:  [-768.91077162]
# Episode:  183 Time:  200 Reward:  [-676.1323187]
# Episode:  184 Time:  200 Reward:  [-391.50357404]
# Episode:  185 Time:  200 Reward:  [-929.01037033]
# Episode:  186 Time:  200 Reward:  [-508.16208225]
# Episode:  187 Time:  200 Reward:  [-898.60464083]
# Episode:  188 Time:  200 Reward:  [-767.90565237]
# Episode:  189 Time:  200 Reward:  [-510.00511215]
# Episode:  190 Time:  200 Reward:  [-812.0952506]
# Episode:  191 Time:  200 Reward:  [-494.76601587]
# Episode:  192 Time:  200 Reward:  [-749.58979262]
# Episode:  193 Time:  200 Reward:  [-790.93137943]
# Episode:  194 Time:  200 Reward:  [-718.74199645]
# Episode:  195 Time:  200 Reward:  [-511.78984202]
# Episode:  196 Time:  200 Reward:  [-512.28301979]
# Episode:  197 Time:  200 Reward:  [-640.69221169]
# Episode:  198 Time:  200 Reward:  [-127.81676453]
# Episode:  199 Time:  200 Reward:  [-768.53524265]
# Episode:  200 Time:  200 Reward:  [-643.82048194]
# Episode:  201 Time:  200 Reward:  [-633.38598124]
# Episode:  202 Time:  200 Reward:  [-383.5184615]
# Episode:  203 Time:  200 Reward:  [-758.42966863]
# Episode:  204 Time:  200 Reward:  [-934.08207201]
# Episode:  205 Time:  200 Reward:  [-323.09520881]
# Episode:  206 Time:  200 Reward:  [-516.63220912]
# Episode:  207 Time:  200 Reward:  [-1076.87325195]
# Episode:  208 Time:  200 Reward:  [-1056.45366049]
# Episode:  209 Time:  200 Reward:  [-1203.80688621]
# Episode:  210 Time:  200 Reward:  [-1106.7149523]
# Episode:  211 Time:  200 Reward:  [-898.25181649]
# Episode:  212 Time:  200 Reward:  [-883.035531]
# Episode:  213 Time:  200 Reward:  [-633.30126706]
# Episode:  214 Time:  200 Reward:  [-1061.43037221]
# Episode:  215 Time:  200 Reward:  [-915.15448585]
# Episode:  216 Time:  200 Reward:  [-762.42424693]
# Episode:  217 Time:  200 Reward:  [-513.32439306]
# Episode:  218 Time:  200 Reward:  [-383.33478503]
# Episode:  219 Time:  200 Reward:  [-859.64322203]
# Episode:  220 Time:  200 Reward:  [-1198.79560176]
# Episode:  221 Time:  200 Reward:  [-1036.06056481]
# Episode:  222 Time:  200 Reward:  [-719.93757654]
# Episode:  223 Time:  200 Reward:  [-787.99561444]
# Episode:  224 Time:  200 Reward:  [-392.09689317]
# Episode:  225 Time:  200 Reward:  [-262.23325417]
# Episode:  226 Time:  200 Reward:  [-261.17397571]
# Episode:  227 Time:  200 Reward:  [-376.39345618]
# Episode:  228 Time:  200 Reward:  [-512.76524308]
# Episode:  229 Time:  200 Reward:  [-253.05345526]
# Episode:  230 Time:  200 Reward:  [-388.48552476]
# Episode:  231 Time:  200 Reward:  [-256.75197561]
# Episode:  232 Time:  200 Reward:  [-513.83574951]
# Episode:  233 Time:  200 Reward:  [-813.36948277]
# Episode:  234 Time:  200 Reward:  [-388.93252301]
# Episode:  235 Time:  200 Reward:  [-129.85619173]
# Episode:  236 Time:  200 Reward:  [-389.59757634]
# Episode:  237 Time:  200 Reward:  [-127.43406356]
# Episode:  238 Time:  200 Reward:  [-629.29577033]
# Episode:  239 Time:  200 Reward:  [-269.34725065]
# Episode:  240 Time:  200 Reward:  [-130.66452449]
# Episode:  241 Time:  200 Reward:  [-260.8769536]
# Episode:  242 Time:  200 Reward:  [-770.17501151]
# Episode:  243 Time:  200 Reward:  [-384.64067998]
# Episode:  244 Time:  200 Reward:  [-576.94786401]
# Episode:  245 Time:  200 Reward:  [-398.92692063]
# Episode:  246 Time:  200 Reward:  [-390.29698235]
# Episode:  247 Time:  200 Reward:  [-497.90564014]
# Episode:  248 Time:  200 Reward:  [-254.25698725]
# Episode:  249 Time:  200 Reward:  [-379.18972663]
# Episode:  250 Time:  200 Reward:  [-379.13382682]
# Episode:  251 Time:  200 Reward:  [-259.93295906]
# Episode:  252 Time:  200 Reward:  [-391.54735425]
# Episode:  253 Time:  200 Reward:  [-253.51614303]
# Episode:  254 Time:  200 Reward:  [-255.41442502]
# Episode:  255 Time:  200 Reward:  [-270.94215348]
# Episode:  256 Time:  200 Reward:  [-0.5223366]
# Episode:  257 Time:  200 Reward:  [-261.21852984]
# Episode:  258 Time:  200 Reward:  [-1205.21092792]
# Episode:  259 Time:  200 Reward:  [-1109.69266211]
# Episode:  260 Time:  200 Reward:  [-1058.70238011]
# Episode:  261 Time:  200 Reward:  [-542.87977109]
# Episode:  262 Time:  200 Reward:  [-127.30176345]
# Episode:  263 Time:  200 Reward:  [-0.92939906]
# Episode:  264 Time:  200 Reward:  [-261.80548681]
# Episode:  265 Time:  200 Reward:  [-5.89790153]
# Episode:  266 Time:  200 Reward:  [-269.78154512]
# Episode:  267 Time:  200 Reward:  [-927.71152208]
# Episode:  268 Time:  200 Reward:  [-591.77758334]
# Episode:  269 Time:  200 Reward:  [-1041.35419347]
# Episode:  270 Time:  200 Reward:  [-634.80634893]
# Episode:  271 Time:  200 Reward:  [-7.6426759]
# Episode:  272 Time:  200 Reward:  [-393.16261831]
# Episode:  273 Time:  200 Reward:  [-516.48873448]
# Episode:  274 Time:  200 Reward:  [-843.92331443]
# Episode:  275 Time:  200 Reward:  [-649.60454526]
# Episode:  276 Time:  200 Reward:  [-641.15071685]
# Episode:  277 Time:  200 Reward:  [-394.48237318]
# Episode:  278 Time:  200 Reward:  [-653.21932219]
# Episode:  279 Time:  200 Reward:  [-650.42018777]
# Episode:  280 Time:  200 Reward:  [-522.98527201]
# Episode:  281 Time:  200 Reward:  [-649.99540198]
# Episode:  282 Time:  200 Reward:  [-519.43874163]
# Episode:  283 Time:  200 Reward:  [-664.34399351]
# Episode:  284 Time:  200 Reward:  [-774.255593]
# Episode:  285 Time:  200 Reward:  [-580.42473815]
# Episode:  286 Time:  200 Reward:  [-527.34200908]
# Episode:  287 Time:  200 Reward:  [-269.71646978]
# Episode:  288 Time:  200 Reward:  [-137.869378]
# Episode:  289 Time:  200 Reward:  [-924.28977231]
# Episode:  290 Time:  200 Reward:  [-135.89678284]
# Episode:  291 Time:  200 Reward:  [-132.6341594]
# Episode:  292 Time:  200 Reward:  [-261.00573637]
# Episode:  293 Time:  200 Reward:  [-1.73275078]
# Episode:  294 Time:  200 Reward:  [-125.68942161]
# Episode:  295 Time:  200 Reward:  [-4.23454556]
# Episode:  296 Time:  200 Reward:  [-1004.51302902]
# Episode:  297 Time:  200 Reward:  [-267.84768037]
# Episode:  298 Time:  200 Reward:  [-1192.18719351]
# Episode:  299 Time:  200 Reward:  [-127.58655342]
# Episode:  300 Time:  200 Reward:  [-415.8225473]
# Episode:  301 Time:  200 Reward:  [-1066.34604118]
# Episode:  302 Time:  200 Reward:  [-1189.07188411]
# Episode:  303 Time:  200 Reward:  [-1107.45900113]
# Episode:  304 Time:  200 Reward:  [-1088.18260357]
# Episode:  305 Time:  200 Reward:  [-1066.52903929]
# Episode:  306 Time:  200 Reward:  [-671.31774692]
# Episode:  307 Time:  200 Reward:  [-2.75369072]
# Episode:  308 Time:  200 Reward:  [-721.9733269]
# Episode:  309 Time:  200 Reward:  [-260.62476662]
# Episode:  310 Time:  200 Reward:  [-993.56192382]
# Episode:  311 Time:  200 Reward:  [-387.80454298]
# Episode:  312 Time:  200 Reward:  [-512.8135283]
# Episode:  313 Time:  200 Reward:  [-129.61678519]
# Episode:  314 Time:  200 Reward:  [-502.19935203]
# Episode:  315 Time:  200 Reward:  [-259.38969678]
# Episode:  316 Time:  200 Reward:  [-128.14000148]
# Episode:  317 Time:  200 Reward:  [-389.10565822]
# Episode:  318 Time:  200 Reward:  [-259.45930563]
# Episode:  319 Time:  200 Reward:  [-371.30350464]
# Episode:  320 Time:  200 Reward:  [-630.30961304]
# Episode:  321 Time:  200 Reward:  [-384.11341539]
# Episode:  322 Time:  200 Reward:  [-129.18973209]
# Episode:  323 Time:  200 Reward:  [-369.4961274]
# Episode:  324 Time:  200 Reward:  [-377.26244414]
# Episode:  325 Time:  200 Reward:  [-251.59172778]
# Episode:  326 Time:  200 Reward:  [-252.33407589]
# Episode:  327 Time:  200 Reward:  [-127.2926074]
# Episode:  328 Time:  200 Reward:  [-406.45621942]
# Episode:  329 Time:  200 Reward:  [-317.69907313]
# Episode:  330 Time:  200 Reward:  [-930.02116765]
# Episode:  331 Time:  200 Reward:  [-1177.28547831]
# Episode:  332 Time:  200 Reward:  [-1057.35694925]
# Episode:  333 Time:  200 Reward:  [-646.35840064]
# Episode:  334 Time:  200 Reward:  [-388.50716194]
# Episode:  335 Time:  200 Reward:  [-8.87954398]
# Episode:  336 Time:  200 Reward:  [-260.69073869]
# Episode:  337 Time:  200 Reward:  [-397.08049138]
# Episode:  338 Time:  200 Reward:  [-425.11868639]
# Episode:  339 Time:  200 Reward:  [-415.03100268]
# Episode:  340 Time:  200 Reward:  [-2.13201046]
# Episode:  341 Time:  200 Reward:  [-521.99016631]
# Episode:  342 Time:  200 Reward:  [-371.36322307]
# Episode:  343 Time:  200 Reward:  [-514.32514132]
# Episode:  344 Time:  200 Reward:  [-259.79230944]
# Episode:  345 Time:  200 Reward:  [-384.94378766]
# Episode:  346 Time:  200 Reward:  [-378.50363324]
# Episode:  347 Time:  200 Reward:  [-391.47772747]
# Episode:  348 Time:  200 Reward:  [-366.01771717]
# Episode:  349 Time:  200 Reward:  [-394.46050308]
# Episode:  350 Time:  200 Reward:  [-917.25450728]
# Episode:  351 Time:  200 Reward:  [-0.30515135]
# Episode:  352 Time:  200 Reward:  [-255.61313105]
# Episode:  353 Time:  200 Reward:  [-125.99139582]
# Episode:  354 Time:  200 Reward:  [-118.63499486]
# Episode:  355 Time:  200 Reward:  [-128.75024774]
# Episode:  356 Time:  200 Reward:  [-383.79407699]
# Episode:  357 Time:  200 Reward:  [-129.24357227]
# Episode:  358 Time:  200 Reward:  [-257.94943485]
# Episode:  359 Time:  200 Reward:  [-257.85744467]
# Episode:  360 Time:  200 Reward:  [-887.18083357]
# Episode:  361 Time:  200 Reward:  [-128.53666874]
# Episode:  362 Time:  200 Reward:  [-129.28441174]
# Episode:  363 Time:  200 Reward:  [-1055.20208874]
# Episode:  364 Time:  200 Reward:  [-367.82932918]
# Episode:  365 Time:  200 Reward:  [-126.03971242]
# Episode:  366 Time:  200 Reward:  [-943.74749451]
# Episode:  367 Time:  200 Reward:  [-260.39362699]
# Episode:  368 Time:  200 Reward:  [-262.39154255]
# Episode:  369 Time:  200 Reward:  [-132.14402646]
# Episode:  370 Time:  200 Reward:  [-251.68874166]
# Episode:  371 Time:  200 Reward:  [-128.46572559]
# Episode:  372 Time:  200 Reward:  [-257.20642276]
# Episode:  373 Time:  200 Reward:  [-128.85715578]
# Episode:  374 Time:  200 Reward:  [-0.17499912]
# Episode:  375 Time:  200 Reward:  [-264.33932203]
# Episode:  376 Time:  200 Reward:  [-2.07874594]
# Episode:  377 Time:  200 Reward:  [-3.45949089]
# Episode:  378 Time:  200 Reward:  [-4.49144243]
# Episode:  379 Time:  200 Reward:  [-132.50623673]
# Episode:  380 Time:  200 Reward:  [-255.85055139]
# Episode:  381 Time:  200 Reward:  [-131.84362923]
# Episode:  382 Time:  200 Reward:  [-505.06210987]
# Episode:  383 Time:  200 Reward:  [-260.55898794]
# Episode:  384 Time:  200 Reward:  [-511.54462268]
# Episode:  385 Time:  200 Reward:  [-1201.91581159]
# Episode:  386 Time:  200 Reward:  [-136.37031131]
# Episode:  387 Time:  200 Reward:  [-265.86442234]
# Episode:  388 Time:  200 Reward:  [-1256.09674238]
# Episode:  389 Time:  200 Reward:  [-126.31267646]
# Episode:  390 Time:  200 Reward:  [-1011.50247618]
# Episode:  391 Time:  200 Reward:  [-6.41571764]
# Episode:  392 Time:  200 Reward:  [-244.9015819]
# Episode:  393 Time:  200 Reward:  [-652.02219012]
# Episode:  394 Time:  200 Reward:  [-1081.74617538]
# Episode:  395 Time:  200 Reward:  [-1085.75204646]
# Episode:  396 Time:  200 Reward:  [-381.64656299]
# Episode:  397 Time:  200 Reward:  [-129.6142953]
# Episode:  398 Time:  200 Reward:  [-1.65089255]
# Episode:  399 Time:  200 Reward:  [-129.30453377]
# Episode:  400 Time:  200 Reward:  [-385.43642678]
# Episode:  401 Time:  200 Reward:  [-1.13758462]
# Episode:  402 Time:  200 Reward:  [-256.19297606]
# Episode:  403 Time:  200 Reward:  [-398.35951414]
# Episode:  404 Time:  200 Reward:  [-129.66552103]
# Episode:  405 Time:  200 Reward:  [-126.33186359]
# Episode:  406 Time:  200 Reward:  [-127.46812349]
# Episode:  407 Time:  200 Reward:  [-382.49251075]
# Episode:  408 Time:  200 Reward:  [-131.60874634]
# Episode:  409 Time:  200 Reward:  [-127.59705761]
# Episode:  410 Time:  200 Reward:  [-494.68166883]
# Episode:  411 Time:  200 Reward:  [-131.35973837]
# Episode:  412 Time:  200 Reward:  [-270.69271529]
# Episode:  413 Time:  200 Reward:  [-268.51927242]
# Episode:  414 Time:  200 Reward:  [-260.15905495]
# Episode:  415 Time:  200 Reward:  [-912.92390412]
# Episode:  416 Time:  200 Reward:  [-127.4389836]
# Episode:  417 Time:  200 Reward:  [-392.58896645]
# Episode:  418 Time:  200 Reward:  [-398.16409669]
# Episode:  419 Time:  200 Reward:  [-763.64767769]
# Episode:  420 Time:  200 Reward:  [-131.72874964]
# Episode:  421 Time:  200 Reward:  [-136.30184315]
# Episode:  422 Time:  200 Reward:  [-393.10351872]
# Episode:  423 Time:  200 Reward:  [-126.85122328]
# Episode:  424 Time:  200 Reward:  [-519.53601828]
# Episode:  425 Time:  200 Reward:  [-909.22825776]
# Episode:  426 Time:  200 Reward:  [-263.99676835]
# Episode:  427 Time:  200 Reward:  [-262.6542604]
# Episode:  428 Time:  200 Reward:  [-7.62695142]
# Episode:  429 Time:  200 Reward:  [-1089.86265346]
# Episode:  430 Time:  200 Reward:  [-521.54360988]
# Episode:  431 Time:  200 Reward:  [-383.59048976]
# Episode:  432 Time:  200 Reward:  [-258.10895543]
# Episode:  433 Time:  200 Reward:  [-983.64766224]
# Episode:  434 Time:  200 Reward:  [-130.91449635]
# Episode:  435 Time:  200 Reward:  [-421.83663165]
# Episode:  436 Time:  200 Reward:  [-385.75239912]
# Episode:  437 Time:  200 Reward:  [-130.40704747]
# Episode:  438 Time:  200 Reward:  [-1.5314671]
# Episode:  439 Time:  200 Reward:  [-422.02822762]
# Episode:  440 Time:  200 Reward:  [-2.84982013]
# Episode:  441 Time:  200 Reward:  [-6.28005536]
# Episode:  442 Time:  200 Reward:  [-504.64254133]
# Episode:  443 Time:  200 Reward:  [-485.41069756]
# Episode:  444 Time:  200 Reward:  [-132.61816061]
# Episode:  445 Time:  200 Reward:  [-525.5382313]
# Episode:  446 Time:  200 Reward:  [-663.72455236]
# Episode:  447 Time:  200 Reward:  [-275.14190287]
# Episode:  448 Time:  200 Reward:  [-421.803605]
# Episode:  449 Time:  200 Reward:  [-908.70507208]
# Episode:  450 Time:  200 Reward:  [-1.94477052]
# Episode:  451 Time:  200 Reward:  [-134.04454423]
# Episode:  452 Time:  200 Reward:  [-397.09653321]
# Episode:  453 Time:  200 Reward:  [-423.72430616]
# Episode:  454 Time:  200 Reward:  [-132.66861821]
# Episode:  455 Time:  200 Reward:  [-457.79457182]
# Episode:  456 Time:  200 Reward:  [-832.9223704]
# Episode:  457 Time:  200 Reward:  [-123.04685792]
# Episode:  458 Time:  200 Reward:  [-2.86510571]
# Episode:  459 Time:  200 Reward:  [-381.40907639]
# Episode:  460 Time:  200 Reward:  [-131.27547662]
# Episode:  461 Time:  200 Reward:  [-127.15522358]
# Episode:  462 Time:  200 Reward:  [-373.66131546]
# Episode:  463 Time:  200 Reward:  [-266.24227614]
# Episode:  464 Time:  200 Reward:  [-267.83584918]
# Episode:  465 Time:  200 Reward:  [-524.75610654]
# Episode:  466 Time:  200 Reward:  [-127.48369588]
# Episode:  467 Time:  200 Reward:  [-394.99024709]
# Episode:  468 Time:  200 Reward:  [-131.45034803]
# Episode:  469 Time:  200 Reward:  [-380.38803965]
# Episode:  470 Time:  200 Reward:  [-131.59799784]
# Episode:  471 Time:  200 Reward:  [-515.17350156]
# Episode:  472 Time:  200 Reward:  [-255.25662108]
# Episode:  473 Time:  200 Reward:  [-379.93509662]
# Episode:  474 Time:  200 Reward:  [-251.84323848]
# Episode:  475 Time:  200 Reward:  [-509.00633014]
# Episode:  476 Time:  200 Reward:  [-268.52176494]
# Episode:  477 Time:  200 Reward:  [-504.57241692]
# Episode:  478 Time:  200 Reward:  [-263.28629769]
# Episode:  479 Time:  200 Reward:  [-515.41046567]
# Episode:  480 Time:  200 Reward:  [-607.45898363]
# Episode:  481 Time:  200 Reward:  [-389.89041941]
# Episode:  482 Time:  200 Reward:  [-394.22888464]
# Episode:  483 Time:  200 Reward:  [-151.26030403]
# Episode:  484 Time:  200 Reward:  [-6.00255278]
# Episode:  485 Time:  200 Reward:  [-252.21037848]
# Episode:  486 Time:  200 Reward:  [-127.30787297]
# Episode:  487 Time:  200 Reward:  [-130.01646803]
# Episode:  488 Time:  200 Reward:  [-263.41501036]
# Episode:  489 Time:  200 Reward:  [-134.00062778]
# Episode:  490 Time:  200 Reward:  [-269.34547958]
# Episode:  491 Time:  200 Reward:  [-239.25714929]
# Episode:  492 Time:  200 Reward:  [-260.85131643]
# Episode:  493 Time:  200 Reward:  [-128.8321175]
# Episode:  494 Time:  200 Reward:  [-249.23691789]
# Episode:  495 Time:  200 Reward:  [-5.93187723]
# Episode:  496 Time:  200 Reward:  [-5.69077052]
# Episode:  497 Time:  200 Reward:  [-4.8714059]
# Episode:  498 Time:  200 Reward:  [-1146.44354105]
# Episode:  499 Time:  200 Reward:  [-256.52779934]
# Episode:  500 Time:  200 Reward:  [-262.97668345]
# Episode:  501 Time:  200 Reward:  [-6.19581311]
# Episode:  502 Time:  200 Reward:  [-1219.0221777]
# Episode:  503 Time:  200 Reward:  [-380.72773249]
# Episode:  504 Time:  200 Reward:  [-383.23678346]
# Episode:  505 Time:  200 Reward:  [-518.35352803]
# Episode:  506 Time:  200 Reward:  [-266.57203913]
# Episode:  507 Time:  200 Reward:  [-1172.80239137]
# Episode:  508 Time:  200 Reward:  [-1208.45657495]
# Episode:  509 Time:  200 Reward:  [-272.00186627]
# Episode:  510 Time:  200 Reward:  [-960.39579744]
# Episode:  511 Time:  200 Reward:  [-260.0446006]
# Episode:  512 Time:  200 Reward:  [-10.54556601]
# Episode:  513 Time:  200 Reward:  [-264.21289237]
# Episode:  514 Time:  200 Reward:  [-270.72034946]
# Episode:  515 Time:  200 Reward:  [-260.98749944]
# Episode:  516 Time:  200 Reward:  [-258.11388739]
# Episode:  517 Time:  200 Reward:  [-506.99905162]
# Episode:  518 Time:  200 Reward:  [-4.32124096]
# Episode:  519 Time:  200 Reward:  [-384.80269566]
# Episode:  520 Time:  200 Reward:  [-261.26764896]
# Episode:  521 Time:  200 Reward:  [-132.76839067]
# Episode:  522 Time:  200 Reward:  [-253.81703381]
# Episode:  523 Time:  200 Reward:  [-267.24315251]
# Episode:  524 Time:  200 Reward:  [-402.70578162]
# Episode:  525 Time:  200 Reward:  [-950.55348066]
# Episode:  526 Time:  200 Reward:  [-1.00361062]
# Episode:  527 Time:  200 Reward:  [-535.92021048]
# Episode:  528 Time:  200 Reward:  [-430.90693751]
# Episode:  529 Time:  200 Reward:  [-126.33512543]
# Episode:  530 Time:  200 Reward:  [-122.01720192]
# Episode:  531 Time:  200 Reward:  [-126.58317621]
# Episode:  532 Time:  200 Reward:  [-2.87193448]
# Episode:  533 Time:  200 Reward:  [-254.55607973]
# Episode:  534 Time:  200 Reward:  [-433.1432872]
# Episode:  535 Time:  200 Reward:  [-247.24215982]
# Episode:  536 Time:  200 Reward:  [-261.18041047]
# Episode:  537 Time:  200 Reward:  [-1098.39164921]
# Episode:  538 Time:  200 Reward:  [-1222.87331378]
# Episode:  539 Time:  200 Reward:  [-382.40418515]
# Episode:  540 Time:  200 Reward:  [-1112.74214651]
# Episode:  541 Time:  200 Reward:  [-131.09406409]
# Episode:  542 Time:  200 Reward:  [-255.9406691]
# Episode:  543 Time:  200 Reward:  [-263.33394129]
# Episode:  544 Time:  200 Reward:  [-120.63840166]
# Episode:  545 Time:  200 Reward:  [-1079.41301992]
# Episode:  546 Time:  200 Reward:  [-130.57171299]
# Episode:  547 Time:  200 Reward:  [-1043.94981297]
# Episode:  548 Time:  200 Reward:  [-3.82941778]
# Episode:  549 Time:  200 Reward:  [-124.81873421]
# Episode:  550 Time:  200 Reward:  [-374.1406686]
# Episode:  551 Time:  200 Reward:  [-252.22759585]
# Episode:  552 Time:  200 Reward:  [-1230.49723333]
# Episode:  553 Time:  200 Reward:  [-357.97488994]
# Episode:  554 Time:  200 Reward:  [-509.7935815]
# Episode:  555 Time:  200 Reward:  [-121.28522757]
# Episode:  556 Time:  200 Reward:  [-119.20562493]
# Episode:  557 Time:  200 Reward:  [-1290.19037656]
# Episode:  558 Time:  200 Reward:  [-1189.70149096]
# Episode:  559 Time:  200 Reward:  [-282.95944904]
# Episode:  560 Time:  200 Reward:  [-127.74703753]
# Episode:  561 Time:  200 Reward:  [-1210.40582617]
# Episode:  562 Time:  200 Reward:  [-127.2267688]
# Episode:  563 Time:  200 Reward:  [-296.76592529]
# Episode:  564 Time:  200 Reward:  [-130.76890776]
# Episode:  565 Time:  200 Reward:  [-246.51618311]
# Episode:  566 Time:  200 Reward:  [-122.04158984]
# Episode:  567 Time:  200 Reward:  [-132.55898532]
# Episode:  568 Time:  200 Reward:  [-130.55200403]
# Episode:  569 Time:  200 Reward:  [-129.31964733]
# Episode:  570 Time:  200 Reward:  [-517.86557778]
# Episode:  571 Time:  200 Reward:  [-133.63662807]
# Episode:  572 Time:  200 Reward:  [-136.3352578]
# Episode:  573 Time:  200 Reward:  [-449.14196572]
# Episode:  574 Time:  200 Reward:  [-136.58613713]
# Episode:  575 Time:  200 Reward:  [-126.57244776]
# Episode:  576 Time:  200 Reward:  [-133.00529506]
# Episode:  577 Time:  200 Reward:  [-273.78212349]
# Episode:  578 Time:  200 Reward:  [-131.25642231]
# Episode:  579 Time:  200 Reward:  [-910.3826047]
# Episode:  580 Time:  200 Reward:  [-132.39979653]
# Episode:  581 Time:  200 Reward:  [-416.7888341]
# Episode:  582 Time:  200 Reward:  [-264.25660282]
# Episode:  583 Time:  200 Reward:  [-260.9541033]
# Episode:  584 Time:  200 Reward:  [-134.55226035]
# Episode:  585 Time:  200 Reward:  [-520.20704079]
# Episode:  586 Time:  200 Reward:  [-129.44418858]
# Episode:  587 Time:  200 Reward:  [-259.07627538]
# Episode:  588 Time:  200 Reward:  [-132.01853564]
# Episode:  589 Time:  200 Reward:  [-260.00046106]
# Episode:  590 Time:  200 Reward:  [-527.73073119]
# Episode:  591 Time:  200 Reward:  [-381.66317628]
# Episode:  592 Time:  200 Reward:  [-263.66307071]
# Episode:  593 Time:  200 Reward:  [-261.28808943]
# Episode:  594 Time:  200 Reward:  [-390.34396084]
# Episode:  595 Time:  200 Reward:  [-394.07736813]
# Episode:  596 Time:  200 Reward:  [-259.49997669]
# Episode:  597 Time:  200 Reward:  [-6.76225292]
# Episode:  598 Time:  200 Reward:  [-128.58540064]
# Episode:  599 Time:  200 Reward:  [-258.0839913]
# Episode:  600 Time:  200 Reward:  [-380.42421565]
# Episode:  601 Time:  200 Reward:  [-132.13886944]
# Episode:  602 Time:  200 Reward:  [-129.24227664]
# Episode:  603 Time:  200 Reward:  [-128.56877241]
# Episode:  604 Time:  200 Reward:  [-264.86098374]
# Episode:  605 Time:  200 Reward:  [-126.52134551]
# Episode:  606 Time:  200 Reward:  [-127.05133044]
# Episode:  607 Time:  200 Reward:  [-124.22517028]
# Episode:  608 Time:  200 Reward:  [-127.73004641]
# Episode:  609 Time:  200 Reward:  [-251.88653459]
# Episode:  610 Time:  200 Reward:  [-256.02533837]
# Episode:  611 Time:  200 Reward:  [-131.34542115]
# Episode:  612 Time:  200 Reward:  [-259.55450308]
# Episode:  613 Time:  200 Reward:  [-131.94911828]
# Episode:  614 Time:  200 Reward:  [-129.9983258]
# Episode:  615 Time:  200 Reward:  [-376.08714173]
# Episode:  616 Time:  200 Reward:  [-253.59444063]
# Episode:  617 Time:  200 Reward:  [-262.01400778]
# Episode:  618 Time:  200 Reward:  [-249.59452573]
# Episode:  619 Time:  200 Reward:  [-261.03513987]
# Episode:  620 Time:  200 Reward:  [-134.53654242]
# Episode:  621 Time:  200 Reward:  [-133.44147]
# Episode:  622 Time:  200 Reward:  [-270.67336044]
# Episode:  623 Time:  200 Reward:  [-134.60845637]
# Episode:  624 Time:  200 Reward:  [-258.57581642]
# Episode:  625 Time:  200 Reward:  [-264.40655081]
# Episode:  626 Time:  200 Reward:  [-264.60900095]
# Episode:  627 Time:  200 Reward:  [-268.91716886]
# Episode:  628 Time:  200 Reward:  [-4.41396582]
# Episode:  629 Time:  200 Reward:  [-457.42759819]
# Episode:  630 Time:  200 Reward:  [-129.64239535]
# Episode:  631 Time:  200 Reward:  [-130.75170182]
# Episode:  632 Time:  200 Reward:  [-2.3433338]
# Episode:  633 Time:  200 Reward:  [-128.35978024]
# Episode:  634 Time:  200 Reward:  [-372.99885282]
# Episode:  635 Time:  200 Reward:  [-443.86214972]
# Episode:  636 Time:  200 Reward:  [-369.04069976]
# Episode:  637 Time:  200 Reward:  [-131.29672177]
# Episode:  638 Time:  200 Reward:  [-125.67285373]
# Episode:  639 Time:  200 Reward:  [-129.12506675]
# Episode:  640 Time:  200 Reward:  [-128.58102423]
# Episode:  641 Time:  200 Reward:  [-262.9073793]
# Episode:  642 Time:  200 Reward:  [-254.80358433]
# Episode:  643 Time:  200 Reward:  [-488.21159777]
# Episode:  644 Time:  200 Reward:  [-374.10963525]
# Episode:  645 Time:  200 Reward:  [-0.94286356]
# Episode:  646 Time:  200 Reward:  [-129.82703824]
# Episode:  647 Time:  200 Reward:  [-373.44946707]
# Episode:  648 Time:  200 Reward:  [-253.82094241]
# Episode:  649 Time:  200 Reward:  [-127.6447128]
# Episode:  650 Time:  200 Reward:  [-252.03111213]
# Episode:  651 Time:  200 Reward:  [-0.90385888]
# Episode:  652 Time:  200 Reward:  [-3.31477646]
# Episode:  653 Time:  200 Reward:  [-131.05869726]
# Episode:  654 Time:  200 Reward:  [-129.89783473]
# Episode:  655 Time:  200 Reward:  [-125.11390531]
# Episode:  656 Time:  200 Reward:  [-383.20864575]
# Episode:  657 Time:  200 Reward:  [-267.79821188]
# Episode:  658 Time:  200 Reward:  [-0.48717537]
# Episode:  659 Time:  200 Reward:  [-1073.79155087]
# Episode:  660 Time:  200 Reward:  [-580.12543699]
# Episode:  661 Time:  200 Reward:  [-127.05247742]
# Episode:  662 Time:  200 Reward:  [-0.77904883]
# Episode:  663 Time:  200 Reward:  [-130.41282204]
# Episode:  664 Time:  200 Reward:  [-392.4361455]
# Episode:  665 Time:  200 Reward:  [-367.89181648]
# Episode:  666 Time:  200 Reward:  [-614.60961157]
# Episode:  667 Time:  200 Reward:  [-131.88714126]
# Episode:  668 Time:  200 Reward:  [-131.00939192]
# Episode:  669 Time:  200 Reward:  [-637.44827548]
# Episode:  670 Time:  200 Reward:  [-386.3046131]
# Episode:  671 Time:  200 Reward:  [-125.68688669]
# Episode:  672 Time:  200 Reward:  [-394.1569848]
# Episode:  673 Time:  200 Reward:  [-251.73288853]
# Episode:  674 Time:  200 Reward:  [-122.06287837]
# Episode:  675 Time:  200 Reward:  [-2.35329529]
# Episode:  676 Time:  200 Reward:  [-260.16000884]
# Episode:  677 Time:  200 Reward:  [-378.41667051]
# Episode:  678 Time:  200 Reward:  [-391.89995457]
# Episode:  679 Time:  200 Reward:  [-380.97240426]
# Episode:  680 Time:  200 Reward:  [-346.52537489]
# Episode:  681 Time:  200 Reward:  [-127.63670579]
# Episode:  682 Time:  200 Reward:  [-959.32445424]
# Episode:  683 Time:  200 Reward:  [-1203.46724177]
# Episode:  684 Time:  200 Reward:  [-427.51768846]
# Episode:  685 Time:  200 Reward:  [-127.88120301]
# Episode:  686 Time:  200 Reward:  [-1210.17519483]
# Episode:  687 Time:  200 Reward:  [-1142.38182444]
# Episode:  688 Time:  200 Reward:  [-370.43707609]
# Episode:  689 Time:  200 Reward:  [-1153.25372012]
# Episode:  690 Time:  200 Reward:  [-1064.5488937]
# Episode:  691 Time:  200 Reward:  [-397.91883739]
# Episode:  692 Time:  200 Reward:  [-1202.96930019]
# Episode:  693 Time:  200 Reward:  [-128.48028388]
# Episode:  694 Time:  200 Reward:  [-379.06658398]
# Episode:  695 Time:  200 Reward:  [-253.30342866]
# Episode:  696 Time:  200 Reward:  [-386.94825066]
# Episode:  697 Time:  200 Reward:  [-258.50864558]
# Episode:  698 Time:  200 Reward:  [-0.81106131]
# Episode:  699 Time:  200 Reward:  [-661.98146305]
# Episode:  700 Time:  200 Reward:  [-129.29930826]
# Episode:  701 Time:  200 Reward:  [-400.08097158]
# Episode:  702 Time:  200 Reward:  [-569.97873748]
# Episode:  703 Time:  200 Reward:  [-401.13116319]
# Episode:  704 Time:  200 Reward:  [-131.88572193]
# Episode:  705 Time:  200 Reward:  [-658.59411224]
# Episode:  706 Time:  200 Reward:  [-388.27567689]
# Episode:  707 Time:  200 Reward:  [-133.61501974]
# Episode:  708 Time:  200 Reward:  [-275.61723083]
# Episode:  709 Time:  200 Reward:  [-849.20270608]
# Episode:  710 Time:  200 Reward:  [-654.58548513]
# Episode:  711 Time:  200 Reward:  [-268.39452663]
# Episode:  712 Time:  200 Reward:  [-267.17769839]
# Episode:  713 Time:  200 Reward:  [-270.69522331]
# Episode:  714 Time:  200 Reward:  [-135.93562222]
# Episode:  715 Time:  200 Reward:  [-137.78289794]
# Episode:  716 Time:  200 Reward:  [-560.39923247]
# Episode:  717 Time:  200 Reward:  [-392.08246014]
# Episode:  718 Time:  200 Reward:  [-7.17728975]
# Episode:  719 Time:  200 Reward:  [-262.04171208]
# Episode:  720 Time:  200 Reward:  [-2.92151728]
# Episode:  721 Time:  200 Reward:  [-131.09191611]
# Episode:  722 Time:  200 Reward:  [-131.02694084]
# Episode:  723 Time:  200 Reward:  [-130.32989426]
# Episode:  724 Time:  200 Reward:  [-401.91610029]
# Episode:  725 Time:  200 Reward:  [-586.87053802]
# Episode:  726 Time:  200 Reward:  [-289.40591696]
# Episode:  727 Time:  200 Reward:  [-264.24115136]
# Episode:  728 Time:  200 Reward:  [-392.05703249]
# Episode:  729 Time:  200 Reward:  [-132.88129438]
# Episode:  730 Time:  200 Reward:  [-0.60819715]
# Episode:  731 Time:  200 Reward:  [-129.40764001]
# Episode:  732 Time:  200 Reward:  [-393.52039435]
# Episode:  733 Time:  200 Reward:  [-259.66409094]
# Episode:  734 Time:  200 Reward:  [-124.355538]
# Episode:  735 Time:  200 Reward:  [-130.68850649]
# Episode:  736 Time:  200 Reward:  [-267.80921743]
# Episode:  737 Time:  200 Reward:  [-604.68875736]
# Episode:  738 Time:  200 Reward:  [-131.92097209]
# Episode:  739 Time:  200 Reward:  [-384.7826665]
# Episode:  740 Time:  200 Reward:  [-125.71932979]
# Episode:  741 Time:  200 Reward:  [-131.01618556]
# Episode:  742 Time:  200 Reward:  [-523.98483744]
# Episode:  743 Time:  200 Reward:  [-127.32698066]
# Episode:  744 Time:  200 Reward:  [-128.1109813]
# Episode:  745 Time:  200 Reward:  [-133.52590283]
# Episode:  746 Time:  200 Reward:  [-402.99530577]
# Episode:  747 Time:  200 Reward:  [-134.86610831]
# Episode:  748 Time:  200 Reward:  [-405.70578472]
# Episode:  749 Time:  200 Reward:  [-931.26914021]
# Episode:  750 Time:  200 Reward:  [-126.89019343]
# Episode:  751 Time:  200 Reward:  [-256.92711426]
# Episode:  752 Time:  200 Reward:  [-3.60160164]
# Episode:  753 Time:  200 Reward:  [-1101.74762542]
# Episode:  754 Time:  200 Reward:  [-260.99923913]
# Episode:  755 Time:  200 Reward:  [-134.21394365]
# Episode:  756 Time:  200 Reward:  [-923.59218287]
# Episode:  757 Time:  200 Reward:  [-1102.9877062]
# Episode:  758 Time:  200 Reward:  [-929.77330969]
# Episode:  759 Time:  200 Reward:  [-137.56953046]
# Episode:  760 Time:  200 Reward:  [-127.51058549]
# Episode:  761 Time:  200 Reward:  [-131.2760316]
# Episode:  762 Time:  200 Reward:  [-279.88167792]
# Episode:  763 Time:  200 Reward:  [-386.27275074]
# Episode:  764 Time:  200 Reward:  [-126.90972101]
# Episode:  765 Time:  200 Reward:  [-128.82450698]
# Episode:  766 Time:  200 Reward:  [-1060.38934485]
# Episode:  767 Time:  200 Reward:  [-256.5279046]
# Episode:  768 Time:  200 Reward:  [-133.00783749]
# Episode:  769 Time:  200 Reward:  [-432.1834475]
# Episode:  770 Time:  200 Reward:  [-130.3941326]
# Episode:  771 Time:  200 Reward:  [-1.78947792]
# Episode:  772 Time:  200 Reward:  [-129.5336916]
# Episode:  773 Time:  200 Reward:  [-128.08710166]
# Episode:  774 Time:  200 Reward:  [-2.03490964]
# Episode:  775 Time:  200 Reward:  [-3.67745335]
# Episode:  776 Time:  200 Reward:  [-528.54876821]
# Episode:  777 Time:  200 Reward:  [-386.44022795]
# Episode:  778 Time:  200 Reward:  [-382.48134829]
# Episode:  779 Time:  200 Reward:  [-131.46642143]
# Episode:  780 Time:  200 Reward:  [-131.360919]
# Episode:  781 Time:  200 Reward:  [-261.30128633]
# Episode:  782 Time:  200 Reward:  [-379.33156477]
# Episode:  783 Time:  200 Reward:  [-394.20122431]
# Episode:  784 Time:  200 Reward:  [-403.89869804]
# Episode:  785 Time:  200 Reward:  [-130.59448585]
# Episode:  786 Time:  200 Reward:  [-127.14948161]
# Episode:  787 Time:  200 Reward:  [-129.3638287]
# Episode:  788 Time:  200 Reward:  [-249.35175904]
# Episode:  789 Time:  200 Reward:  [-0.86668975]
# Episode:  790 Time:  200 Reward:  [-263.38498769]
# Episode:  791 Time:  200 Reward:  [-127.58558339]
# Episode:  792 Time:  200 Reward:  [-129.97937714]
# Episode:  793 Time:  200 Reward:  [-371.69642384]
# Episode:  794 Time:  200 Reward:  [-1.49413317]
# Episode:  795 Time:  200 Reward:  [-127.95438726]
# Episode:  796 Time:  200 Reward:  [-3.16864987]
# Episode:  797 Time:  200 Reward:  [-387.79731133]
# Episode:  798 Time:  200 Reward:  [-265.03221732]
# Episode:  799 Time:  200 Reward:  [-415.26883047]
# Episode:  800 Time:  200 Reward:  [-246.45187284]
# Episode:  801 Time:  200 Reward:  [-126.58377372]
# Episode:  802 Time:  200 Reward:  [-466.99227328]
# Episode:  803 Time:  200 Reward:  [-1.45304758]
# Episode:  804 Time:  200 Reward:  [-130.84092872]
# Episode:  805 Time:  200 Reward:  [-278.18550194]
# Episode:  806 Time:  200 Reward:  [-128.38601313]
# Episode:  807 Time:  200 Reward:  [-128.03632212]
# Episode:  808 Time:  200 Reward:  [-128.28254912]
# Episode:  809 Time:  200 Reward:  [-129.43406923]
# Episode:  810 Time:  200 Reward:  [-381.46749299]
# Episode:  811 Time:  200 Reward:  [-254.84345241]
# Episode:  812 Time:  200 Reward:  [-131.24481374]
# Episode:  813 Time:  200 Reward:  [-124.5327255]
# Episode:  814 Time:  200 Reward:  [-124.7147594]
# Episode:  815 Time:  200 Reward:  [-928.70644407]
# Episode:  816 Time:  200 Reward:  [-249.7788249]
# Episode:  817 Time:  200 Reward:  [-131.09152178]
# Episode:  818 Time:  200 Reward:  [-122.80283358]
# Episode:  819 Time:  200 Reward:  [-377.96851526]
# Episode:  820 Time:  200 Reward:  [-473.31907837]
# Episode:  821 Time:  200 Reward:  [-253.77091]
# Episode:  822 Time:  200 Reward:  [-1089.63959117]
# Episode:  823 Time:  200 Reward:  [-125.80844429]
# Episode:  824 Time:  200 Reward:  [-935.852575]
# Episode:  825 Time:  200 Reward:  [-128.46503121]
# Episode:  826 Time:  200 Reward:  [-128.77633582]
# Episode:  827 Time:  200 Reward:  [-129.25842315]
# Episode:  828 Time:  200 Reward:  [-126.20153266]
# Episode:  829 Time:  200 Reward:  [-238.13954407]
# Episode:  830 Time:  200 Reward:  [-1028.43075316]
# Episode:  831 Time:  200 Reward:  [-126.77730939]
# Episode:  832 Time:  200 Reward:  [-127.75178997]
# Episode:  833 Time:  200 Reward:  [-3.41863367]
# Episode:  834 Time:  200 Reward:  [-254.93877524]
# Episode:  835 Time:  200 Reward:  [-1085.24918815]
# Episode:  836 Time:  200 Reward:  [-267.56941429]
# Episode:  837 Time:  200 Reward:  [-134.41816752]
# Episode:  838 Time:  200 Reward:  [-251.44350397]
# Episode:  839 Time:  200 Reward:  [-619.34831573]
# Episode:  840 Time:  200 Reward:  [-2.7766174]
# Episode:  841 Time:  200 Reward:  [-3.51278143]
# Episode:  842 Time:  200 Reward:  [-3.39043596]
# Episode:  843 Time:  200 Reward:  [-128.767514]
# Episode:  844 Time:  200 Reward:  [-394.23997457]
# Episode:  845 Time:  200 Reward:  [-126.86300977]
# Episode:  846 Time:  200 Reward:  [-129.46763637]
# Episode:  847 Time:  200 Reward:  [-130.47317159]
# Episode:  848 Time:  200 Reward:  [-262.8605036]
# Episode:  849 Time:  200 Reward:  [-260.14681931]
# Episode:  850 Time:  200 Reward:  [-124.0537304]
# Episode:  851 Time:  200 Reward:  [-131.1659657]
# Episode:  852 Time:  200 Reward:  [-126.95008872]
# Episode:  853 Time:  200 Reward:  [-262.34098758]
# Episode:  854 Time:  200 Reward:  [-264.9584644]
# Episode:  855 Time:  200 Reward:  [-637.20453984]
# Episode:  856 Time:  200 Reward:  [-127.98999875]
# Episode:  857 Time:  200 Reward:  [-131.44895392]
# Episode:  858 Time:  200 Reward:  [-246.7653043]
# Episode:  859 Time:  200 Reward:  [-135.50980227]
# Episode:  860 Time:  200 Reward:  [-270.51870109]
# Episode:  861 Time:  200 Reward:  [-130.39548671]
# Episode:  862 Time:  200 Reward:  [-130.77240132]
# Episode:  863 Time:  200 Reward:  [-1117.58548544]
# Episode:  864 Time:  200 Reward:  [-521.39307691]
# Episode:  865 Time:  200 Reward:  [-378.03679389]
# Episode:  866 Time:  200 Reward:  [-374.99632732]
# Episode:  867 Time:  200 Reward:  [-120.77602627]
# Episode:  868 Time:  200 Reward:  [-267.2459338]
# Episode:  869 Time:  200 Reward:  [-0.9184833]
# Episode:  870 Time:  200 Reward:  [-251.22852358]
# Episode:  871 Time:  200 Reward:  [-257.55474218]
# Episode:  872 Time:  200 Reward:  [-244.08928979]
# Episode:  873 Time:  200 Reward:  [-1.20920372]
# Episode:  874 Time:  200 Reward:  [-261.90155604]
# Episode:  875 Time:  200 Reward:  [-248.30707384]
# Episode:  876 Time:  200 Reward:  [-372.89238859]
# Episode:  877 Time:  200 Reward:  [-128.10326957]
# Episode:  878 Time:  200 Reward:  [-134.46051699]
# Episode:  879 Time:  200 Reward:  [-1216.20241392]
# Episode:  880 Time:  200 Reward:  [-130.43552646]
# Episode:  881 Time:  200 Reward:  [-126.9762288]
# Episode:  882 Time:  200 Reward:  [-1.99627913]
# Episode:  883 Time:  200 Reward:  [-127.02613201]
# Episode:  884 Time:  200 Reward:  [-1.95585085]
# Episode:  885 Time:  200 Reward:  [-272.78813742]
# Episode:  886 Time:  200 Reward:  [-262.22839074]
# Episode:  887 Time:  200 Reward:  [-126.48794917]
# Episode:  888 Time:  200 Reward:  [-395.42290314]
# Episode:  889 Time:  200 Reward:  [-715.27898157]
# Episode:  890 Time:  200 Reward:  [-897.28390678]
# Episode:  891 Time:  200 Reward:  [-646.69039254]
# Episode:  892 Time:  200 Reward:  [-1216.36210379]
# Episode:  893 Time:  200 Reward:  [-1178.74628282]
# Episode:  894 Time:  200 Reward:  [-135.65978608]
# Episode:  895 Time:  200 Reward:  [-1276.11424085]
# Episode:  896 Time:  200 Reward:  [-252.58489061]
# Episode:  897 Time:  200 Reward:  [-1293.10670322]
# Episode:  898 Time:  200 Reward:  [-1232.26577511]
# Episode:  899 Time:  200 Reward:  [-1204.01460818]
# Episode:  900 Time:  200 Reward:  [-259.62464553]
# Episode:  901 Time:  200 Reward:  [-265.31869717]
# Episode:  902 Time:  200 Reward:  [-133.06123484]
# Episode:  903 Time:  200 Reward:  [-371.35739567]
# Episode:  904 Time:  200 Reward:  [-270.53028677]
# Episode:  905 Time:  200 Reward:  [-122.89187752]
# Episode:  906 Time:  200 Reward:  [-375.50319625]
# Episode:  907 Time:  200 Reward:  [-368.65229316]
# Episode:  908 Time:  200 Reward:  [-245.7279699]
# Episode:  909 Time:  200 Reward:  [-126.6599926]
# Episode:  910 Time:  200 Reward:  [-127.28222318]
# Episode:  911 Time:  200 Reward:  [-124.60177259]
# Episode:  912 Time:  200 Reward:  [-1061.42079577]
# Episode:  913 Time:  200 Reward:  [-257.57571486]
# Episode:  914 Time:  200 Reward:  [-126.96349513]
# Episode:  915 Time:  200 Reward:  [-2.03311433]
# Episode:  916 Time:  200 Reward:  [-247.67548807]
# Episode:  917 Time:  200 Reward:  [-0.80949141]
# Episode:  918 Time:  200 Reward:  [-248.46005573]
# Episode:  919 Time:  200 Reward:  [-128.31458134]
# Episode:  920 Time:  200 Reward:  [-467.94151408]
# Episode:  921 Time:  200 Reward:  [-131.44486558]
# Episode:  922 Time:  200 Reward:  [-4.34700515]
# Episode:  923 Time:  200 Reward:  [-376.39465395]
# Episode:  924 Time:  200 Reward:  [-367.25964435]
# Episode:  925 Time:  200 Reward:  [-129.25215424]
# Episode:  926 Time:  200 Reward:  [-482.86669706]
# Episode:  927 Time:  200 Reward:  [-123.65286492]
# Episode:  928 Time:  200 Reward:  [-369.63853897]
# Episode:  929 Time:  200 Reward:  [-241.31574379]
# Episode:  930 Time:  200 Reward:  [-923.03583342]
# Episode:  931 Time:  200 Reward:  [-130.59282373]
# Episode:  932 Time:  200 Reward:  [-129.83007305]
# Episode:  933 Time:  200 Reward:  [-261.99111391]
# Episode:  934 Time:  200 Reward:  [-266.26774197]
# Episode:  935 Time:  200 Reward:  [-433.46030719]
# Episode:  936 Time:  200 Reward:  [-130.40333512]
# Episode:  937 Time:  200 Reward:  [-131.22056882]
# Episode:  938 Time:  200 Reward:  [-482.38678763]
# Episode:  939 Time:  200 Reward:  [-370.38784613]
# Episode:  940 Time:  200 Reward:  [-131.74312874]
# Episode:  941 Time:  200 Reward:  [-242.19562072]
# Episode:  942 Time:  200 Reward:  [-253.16339311]
# Episode:  943 Time:  200 Reward:  [-131.26536085]
# Episode:  944 Time:  200 Reward:  [-249.57799604]
# Episode:  945 Time:  200 Reward:  [-251.16479287]
# Episode:  946 Time:  200 Reward:  [-414.56596197]
# Episode:  947 Time:  200 Reward:  [-131.90235614]
# Episode:  948 Time:  200 Reward:  [-905.0800215]
# Episode:  949 Time:  200 Reward:  [-127.76370685]
# Episode:  950 Time:  200 Reward:  [-130.73193593]
# Episode:  951 Time:  200 Reward:  [-128.0837908]
# Episode:  952 Time:  200 Reward:  [-247.74090264]
# Episode:  953 Time:  200 Reward:  [-399.66009139]
# Episode:  954 Time:  200 Reward:  [-418.096846]
# Episode:  955 Time:  200 Reward:  [-131.62047592]
# Episode:  956 Time:  200 Reward:  [-255.75127712]
# Episode:  957 Time:  200 Reward:  [-129.82002996]
# Episode:  958 Time:  200 Reward:  [-127.31642793]
# Episode:  959 Time:  200 Reward:  [-124.7581324]
# Episode:  960 Time:  200 Reward:  [-1.58504727]
# Episode:  961 Time:  200 Reward:  [-257.98409619]
# Episode:  962 Time:  200 Reward:  [-255.10201429]
# Episode:  963 Time:  200 Reward:  [-256.67654122]
# Episode:  964 Time:  200 Reward:  [-385.84544308]
# Episode:  965 Time:  200 Reward:  [-364.0699639]
# Episode:  966 Time:  200 Reward:  [-265.43847205]
# Episode:  967 Time:  200 Reward:  [-284.31059383]
# Episode:  968 Time:  200 Reward:  [-255.72139987]
# Episode:  969 Time:  200 Reward:  [-2.2751432]
# Episode:  970 Time:  200 Reward:  [-248.54157256]
# Episode:  971 Time:  200 Reward:  [-908.07404784]
# Episode:  972 Time:  200 Reward:  [-295.7899765]
# Episode:  973 Time:  200 Reward:  [-1.06829572]
# Episode:  974 Time:  200 Reward:  [-128.8598124]
# Episode:  975 Time:  200 Reward:  [-127.23960932]
# Episode:  976 Time:  200 Reward:  [-125.1496353]
# Episode:  977 Time:  200 Reward:  [-260.31986441]
# Episode:  978 Time:  200 Reward:  [-129.37489697]
# Episode:  979 Time:  200 Reward:  [-130.05535946]
# Episode:  980 Time:  200 Reward:  [-1191.24175008]
# Episode:  981 Time:  200 Reward:  [-392.5220089]
# Episode:  982 Time:  200 Reward:  [-127.40933322]
# Episode:  983 Time:  200 Reward:  [-1.47267718]
# Episode:  984 Time:  200 Reward:  [-125.27569457]
# Episode:  985 Time:  200 Reward:  [-1214.90231217]
# Episode:  986 Time:  200 Reward:  [-1215.09828694]
# Episode:  987 Time:  200 Reward:  [-129.38726225]
# Episode:  988 Time:  200 Reward:  [-129.38553539]
# Episode:  989 Time:  200 Reward:  [-128.59378334]
# Episode:  990 Time:  200 Reward:  [-129.5899332]
# Episode:  991 Time:  200 Reward:  [-467.45589084]
# Episode:  992 Time:  200 Reward:  [-242.23036104]
# Episode:  993 Time:  200 Reward:  [-246.65891354]
# Episode:  994 Time:  200 Reward:  [-1070.07065738]
# Episode:  995 Time:  200 Reward:  [-258.90996666]
# Episode:  996 Time:  200 Reward:  [-249.44873467]
# Episode:  997 Time:  200 Reward:  [-386.28638886]
# Episode:  998 Time:  200 Reward:  [-259.42158007]
# Episode:  999 Time:  200 Reward:  [-131.02089737]
# Episode:  1000 Time:  200 Reward:  [-772.67566039]
# [array([-1395.96051877]), array([-1233.08959234]), array([-1341.48302513]), array([-1433.95290763]), array([-1747.36646792]), array([-1155.6473278]), array([-1409.72056092]), array([-1794.54102949]), array([-1484.53599404]), array([-1434.22180123]), array([-1254.7725545]), array([-1334.0343137]), array([-1397.7570261]), array([-1200.49362083]), array([-1241.16246762]), array([-1293.27990232]), array([-1220.81788628]), array([-1342.77060769]), array([-1408.74589327]), array([-1510.14110286]), array([-1659.86946001]), array([-1402.06638938]), array([-1443.42749469]), array([-1505.12042869]), array([-1408.46861479]), array([-1439.99401724]), array([-1342.8029064]), array([-1162.55896244]), array([-1862.02982129]), array([-1340.34619604]), array([-1510.13476765]), array([-1692.78103962]), array([-1805.64313087]), array([-1676.39330399]), array([-1859.70573466]), array([-1346.24367149]), array([-1369.04275417]), array([-1702.94221571]), array([-1239.52077504]), array([-1226.84371278]), array([-1156.1568855]), array([-1092.91193263]), array([-1317.73251662]), array([-1189.25098433]), array([-1259.99954456]), array([-1097.79092615]), array([-1716.93930888]), array([-1287.9893454]), array([-1326.49379173]), array([-1266.73203623]), array([-1277.50306853]), array([-1518.30217341]), array([-1491.03677571]), array([-1199.16389087]), array([-1031.1854707]), array([-1494.56664726]), array([-1469.7634743]), array([-1343.7811809]), array([-1321.71902632]), array([-1211.42363483]), array([-1442.56590024]), array([-1414.05520974]), array([-1300.83770657]), array([-1181.5027599]), array([-1306.96635969]), array([-1356.53147496]), array([-1172.48614177]), array([-1310.55925938]), array([-1308.76071879]), array([-1324.04161542]), array([-1263.96261137]), array([-1327.62337434]), array([-1022.48339167]), array([-1090.94550485]), array([-1006.43581192]), array([-1295.234748]), array([-1197.93350774]), array([-1297.45153664]), array([-1303.53530341]), array([-1124.91186805]), array([-1201.78923496]), array([-1318.19926612]), array([-1205.59692745]), array([-1155.99241346]), array([-890.02039804]), array([-1296.72107745]), array([-1259.12105495]), array([-754.35395085]), array([-1188.53188933]), array([-657.56169806]), array([-1109.7715214]), array([-961.78293167]), array([-978.63487295]), array([-628.11182503]), array([-856.54376453]), array([-1123.10208011]), array([-1126.9832052]), array([-1033.58280454]), array([-759.11224587]), array([-969.87746913]), array([-749.88280398]), array([-754.59908911]), array([-1014.37846986]), array([-1023.46548744]), array([-1156.44936873]), array([-770.77239557]), array([-772.66921482]), array([-880.80739676]), array([-877.69213466]), array([-888.30439455]), array([-829.60949531]), array([-849.51183845]), array([-1062.80123733]), array([-896.00822742]), array([-811.88954389]), array([-1237.99707988]), array([-1124.87990701]), array([-1065.4293359]), array([-877.97139086]), array([-737.53063723]), array([-631.69778764]), array([-870.70902648]), array([-1094.69447788]), array([-708.18734888]), array([-742.14447076]), array([-759.59455645]), array([-1077.24064551]), array([-864.27106097]), array([-890.19513684]), array([-865.10784688]), array([-782.56489426]), array([-977.46783659]), array([-912.02649974]), array([-865.46712028]), array([-776.74105432]), array([-1025.96005533]), array([-887.74199698]), array([-996.29421122]), array([-982.13692999]), array([-662.92759248]), array([-870.07859832]), array([-752.49929358]), array([-869.45307963]), array([-271.76411753]), array([-878.76512649]), array([-753.45812678]), array([-747.24974611]), array([-806.25176624]), array([-910.37641741]), array([-628.52872452]), array([-1015.20364166]), array([-736.6398495]), array([-508.82451005]), array([-1016.4278843]), array([-1116.57955851]), array([-761.04373476]), array([-1142.27123577]), array([-1009.14335691]), array([-882.98859587]), array([-903.62128431]), array([-698.57037654]), array([-1171.291694]), array([-765.2129193]), a ...
